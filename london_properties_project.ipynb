# %% [markdown]
# <p id='top'></p>
#
# <h1 align='center'>PROJECT ON AVAILABLE PROPERTIES IN LONDON By BELLO ISMAHEEL</h1>
#
# # PROJECT OUTLINE
#
# 1. [INTRODUCTION](#intro)
# 2. [DATA GATHERING](#collect)
#     - [RIGHTMOVE](#right)
#     - [ZOOPLA](#zoopla)
#     - [ON THE MARKET](#otm)
# 3. [DATA WRANGLING](#wrangle)
#     - [RIGHTMOVE](#wrightmove)
#     - [ZOOPLA](#wzoopla)
#     - [ON THE MARKET](#wotm)
# 4. [DATA MODELLING](#model)
# 5. [END NOTE](#report)

# %% [markdown]
# <p id='intro'</p>
#
# ## INTRODUCTION

# %% [markdown]
# This project is aimed at helping Mappa find her dream home with the Power of Data and Technology, the datasets used for this project was collected from [Rightmove](https://rightmove.co.uk) , [Zoopla](https://zoopla.co.uk) , and [On The Market](https://onthemove.co.uk) websites respectively. Data was collected on properties available for Sale and for rent. The features contained in each Dataset are:
#
# - Transaction type (i.e. sale vs. rent - string)
# - Bedrooms (integer)
# - Bathrooms (integer)
# - Description (free text string)
# - Property type e.g. flat, detached house, terraced house
# - Price e.g. 500,000 (typically integer)
# - Location
# - Agent (advertising the property)
# - Listing source
# - Listing URL

# %% [markdown]
# ### Required packages

# %%
#!pip install geopy
#!pip install selenium
#pip install 'scrapfly-sdk'
import pandas as pd
import numpy as np
import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import time
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from scrapfly import ScrapflyClient
from scrapfly import ScrapflyClient, ScrapeConfig
from urllib.parse import urljoin
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <p id='collect'></p>
#
# ##  DATA GATHERING

# %% [markdown]
# <p id='right'></p>
#
# ### Webscraping rightmove.co.uk

# %%
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3')
service = Service('C:\\Users\\Simplicity\\chromedriver_win32')
driver = webdriver.Chrome(service=service, options=options)

# %% [markdown]
# #### For Sale

# %%
# For Sale

# Set the URL for property search
url = 'https://www.rightmove.co.uk/property-for-sale.html'

# Navigate to the URL
driver.get(url)

# Pause execution for 10 seconds to allow the page to load
time.sleep(10)

# Find and clear the search box, then enter 'London' as the search query
search_box = driver.find_element(By.NAME, 'searchLocation')
search_box.clear()
search_box.send_keys('London')

# Pause execution for 5 seconds
time.sleep(5)

# Submit the search query by pressing the Enter key
search_box.send_keys(Keys.RETURN)

# Find the 'submit' button and click it
click = driver.find_element(By.ID, 'submit')
click.click()

# Pause execution for 10 seconds to allow the search results to load
time.sleep(10)

# Create an empty DataFrame to store property details
df = pd.DataFrame(columns=['Address', 'Type', 'Price', 'No_of_bedroom', 'No_of_bathroom', 'description',
                           'Agent_name', 'Agent_website', 'Agent_contact', 'Listing_url'])

# Loop to scrape property details from multiple pages
while True:
    # Scroll to the bottom of the page
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
    # Pause execution for 2 seconds
    time.sleep(2)
    
    # Get the page source and create a BeautifulSoup object
    html = driver.page_source
    soup = BeautifulSoup(html, "lxml")
    
    # Find all property elements on the page
    prop = re.findall(r"property-\d+", soup.prettify())
    
    # Extract details from each property element
    for i in prop:
        details = {}
        for j in soup.find('div', id=i, class_='l-searchResult is-list'):
            # Extract property details using various CSS selectors
            details['Address'] = [j.find('address', class_="propertyCard-address property-card-updates").text.strip()]
            details['Type'] = [j.find('span', class_="text").text]
            details['Price'] = [j.find('div', class_="propertyCard-priceValue").text]
            
            # Handle cases where the number of bedrooms or bathrooms is not available
            try:
                details['No_of_bedroom'] = [j.find('span', class_="no-svg-bed-icon bed-icon seperator").title.text]
            except AttributeError:
                details['No_of_bedroom'] = [np.NaN]
            try:
                details['No_of_bathroom'] = [j.find('span', class_="no-svg-bathroom-icon bathroom-icon seperator").title.text]
            except AttributeError:
                details['No_of_bathroom'] = [np.NaN]
            
            details['description'] = [j.find('span', itemprop="description").text]
            
            # Handle cases where agent details are not available
            try:
                details['Agent_name'] = [j.find('div', class_='propertyCard-branchLogo').a['title']]
            except AttributeError:
                details['Agent_name'] = [np.NaN]
            try:
                details['Agent_website'] = [re.search(r"([a-zA-Z]+[\W]+[a-zA-Z\.]+)", url).group() + j.find('div', class_='propertyCard-branchLogo').a['href']]
            except AttributeError:
                details['Agent_website'] = [np.NaN]
            try:
                details['Agent_contact'] = [re.search(r"([a-zA-Z]+[\W]+[a-zA-Z\.]+)", url).group() + j.find('a', class_='action mail-icon')['href']]
            except AttributeError:
                details['Agent_contact'] = [np.NaN]
            try:
                details['Listing_url'] = [re.search(r"([a-zA-Z]+[\W]+[a-zA-Z\.]+)", url).group() + j.find('a', class_='propertyCard-priceLink propertyCard-salePrice')['href']]
            except AttributeError:
                details['Listing_url'] = [np.NaN]
            
            # Create a DataFrame with the property details
            details = pd.DataFrame(details)
            df = pd.concat([df, details], ignore_index=True)
    
    # Find the next button for pagination
    button = driver.find_element(By.CSS_SELECTOR, 'button.pagination-button.pagination-direction.pagination-direction--next')
    
    # Check if the next button is disabled (indicating the last page)
    if driver.execute_script("return arguments[0].disabled;", button) == True:
        break
    else:
        # Click the next button to navigate to the next page
        driver.execute_script("arguments[0].click();", button)
    
    # Pause execution for 3 seconds
    time.sleep(3)

# Close the WebDriver
driver.quit()

# Display the first few rows of the DataFrame
df.head()

# %%
df.to_csv('rightmove_sale.csv',index = False)
right_sales = df.copy()

# %% [markdown]
# #### For rent

# %%
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3')
service = Service('C:\\Users\\Simplicity\\chromedriver_win32')
driver = webdriver.Chrome(service=service, options=options)

# %%
# For rent

# Set the URL for property search
url = 'https://www.rightmove.co.uk/property-to-rent.html'

# Navigate to the URL
driver.get(url)

# Find and clear the search box, then enter 'London' as the search query
search_box = driver.find_element(By.NAME, 'searchLocation')
search_box.clear()
search_box.send_keys('London')

# Pause execution for 5 seconds
time.sleep(5)

# Submit the search query by pressing the Enter key
search_box.send_keys(Keys.RETURN)

# Find the 'submit' button and click it
click = driver.find_element(By.ID, 'submit')
click.click()

# Create an empty DataFrame to store property details
df2 = pd.DataFrame(columns=['Address', 'Type', 'Price', 'Price_pw', 'No_of_bedroom', 'No_of_bathroom', 'description',
                            'Agent_name', 'Agent_website', 'Agent_contact', 'Listing_url'])

# Loop to scrape property details from multiple pages
while True:
    # Scroll to the bottom of the page
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
    # Pause execution for 2 seconds
    time.sleep(2)
    
    # Get the page source and create a BeautifulSoup object
    html = driver.page_source
    soup = BeautifulSoup(html, "lxml")
    
    # Find all property elements on the page
    prop = re.findall(r"property-\d+", soup.prettify())
    
    # Extract details from each property element
    for i in prop:
        details = {}
        for j in soup.find('div', id=i, class_='l-searchResult is-list'):
            # Extract property details using various CSS selectors
            details['Address'] = [j.find('address', class_="propertyCard-address property-card-updates").text.strip()]
            details['Type'] = [j.find('span', class_="text").text]
            details['Price'] = [j.find('span', class_="propertyCard-priceValue").text]
            details['Price_pw'] = [j.find('span', class_="propertyCard-secondaryPriceValue").text]
            
            # Handle cases where the number of bedrooms or bathrooms is not available
            try:
                details['No_of_bedroom'] = [j.find('span', class_="no-svg-bed-icon bed-icon seperator").title.text]
            except AttributeError:
                details['No_of_bedroom'] = [np.NaN]
            try:
                details['No_of_bathroom'] = [j.find('span', class_="no-svg-bathroom-icon bathroom-icon seperator").title.text]
            except AttributeError:
                details['No_of_bathroom'] = [np.NaN]
            
            details['description'] = [j.find('span', itemprop="description").text]
            
            # Handle cases where agent details are not available
            try:
                details['Agent_name'] = [j.find('div', class_='propertyCard-branchLogo').a['title']]
            except AttributeError:
                details['Agent_name'] = [np.NaN]
            try:
                details['Agent_website'] = [re.search(r"([a-zA-Z]+[\W]+[a-zA-Z\.]+)", url).group() + j.find('div', class_='propertyCard-branchLogo').a['href']]
            except AttributeError:
                details['Agent_website'] = [np.NaN]
            try:
                details['Agent_contact'] = [re.search(r"([a-zA-Z]+[\W]+[a-zA-Z\.]+)", url).group() + j.find('a', class_='action mail-icon')['href']]
            except AttributeError:
                details['Agent_contact'] = [np.NaN]
            
            # Extract the listing URL
            try:
                details['Listing_url'] = [re.search(r"([a-zA-Z]+[\W]+[a-zA-Z\.]+)", url).group() + j.find('a', class_='propertyCard-link property-card-updates')['href']]
            except AttributeError:
                details['Listing_url'] = [np.NaN]
            
            # Create a DataFrame with the property details
            details = pd.DataFrame(details)
            df2 = pd.concat([df2, details], ignore_index=True)
    
    # Find the next button for pagination
    button = driver.find_element(By.CSS_SELECTOR, 'button.pagination-button.pagination-direction.pagination-direction--next')
    
    # Check if the next button is disabled (indicating the last page)
    if driver.execute_script("return arguments[0].disabled;", button) == True:
        break
    else:
        # Click the next button to navigate to the next page
        driver.execute_script("arguments[0].click();", button)
    
    # Pause execution for 3 seconds
    time.sleep(3)

# Close the WebDriver
driver.quit()

# Display the first few rows of the DataFrame
df2.head()

# %%
df2.to_csv('rightmove_rent.csv',index = False)
right_rent = df2.copy()

# %% [markdown]
# [GoToTop](#top)
#
# <p id='zoopla'></p>
#
# ### Webscraping for zoopla.co.uk

# %% [markdown]
# ### For sale.

# %%
import time
import pandas as pd
import re
import numpy as np
from bs4 import BeautifulSoup
from scrapfly import ScrapflyClient, ScrapeConfig
from urllib.parse import urljoin

# Set up Scrapfly credentials
API_KEY = "MY API KEY"
client = ScrapflyClient(API_KEY)
count = 1
# Set the initial URL
url = 'https://www.zoopla.co.uk/for-sale/property/london/?q=London&search_source=home&pn={}'.format(count)
response = client.scrape(ScrapeConfig(url, country="GB", asp=True))
html = response.content
soup = BeautifulSoup(html, "lxml")
prop = re.findall(r"listing_\d+", soup.prettify())

# Create a DataFrame to store scraped data
sale_zoopla = pd.DataFrame(columns=['Address', 'Price', 'Description', 'Agent_name', 'Agent_website',
                                    'Agent_contact', 'Listing_url', 'No_of_Bedroom', 'No_of_Bathroom',
                                    'No_of_livingroom'])

# Loop to scrape property details from multiple pages
while True:
    # Extract details from each property element
    for i in prop:
        details = {}
        for j in soup.find('div', id=i, class_='f0xnzq2'):
            # Extract property details using CSS selectors
            Address = j.find('h3', class_="_1ankud52 _1ftx2fq9")
            if Address is not None:
                details['Address'] = Address.text.strip()

            # Extract price using CSS selector
            Price = j.find('div', class_="_170k6631")
            if Price is not None:
                details['Price'] = Price.text.strip()

            # Extract description using CSS selector
            description = j.find('h2', class_="_1ankud51 _1ftx2fq8")
            if description is not None:
                details['Description'] = description.text.strip()
            # Extract agent name and website using CSS selector
            Agent_name = j.find('div', class_='fas4ee0')
            if Agent_name is not None:
                img_tag = Agent_name.find('img', class_='_12bxhf70')
            if img_tag is not None:
                details['Agent_name'] = img_tag.get('alt')


            # Extract agent name and website using CSS selector
            Agent_website = j.find('div', class_='fas4ee0')
            if Agent_website is not None:
                details['Agent_website'] = urljoin(url, Agent_website.a['href'])

            # Extract agent contact using CSS selector
            Agent_contact = j.find('a', {'aria-label': 'Contact agent'})
            if Agent_contact is not None:
                details['Agent_contact'] = urljoin(url, Agent_contact['href'])

            # Extract listing URL using CSS selector
            Listing_url = j.find('a', class_='_1maljyt1')
            if Listing_url is not None:
                details['Listing_url'] = urljoin(url, Listing_url['href'])

            # Extract bedroom, bathroom, and living room information using CSS selector
            data = {'Bedrooms': np.NaN, 'Bathrooms': np.NaN, 'Living rooms': np.NaN}
            for item in j.find_all('li', class_='_3fbafd1'):
                value_element = re.search(r"\d+", item.text.strip()).group(0)
                label_element = item.find('span').text.strip()
                if label_element and value_element:
                    label = label_element
                    value = value_element
                    data[label] = value

            details['No_of_Bedroom'] = data['Bedrooms']
            details['No_of_Bathroom'] = data['Bathrooms']
            details['No_of_livingroom'] = data['Living rooms']

            # Create a DataFrame with the property details
            details = pd.DataFrame(details, index=[0])
            sale_zoopla = pd.concat([sale_zoopla, details], ignore_index=True)

    # Find the next page button element
    next_button = soup.find('a', class_="x8jo560 x8jo563 x8jo56a _1ftx2fq8", attrs={"aria-disabled": "false"})

    # Check if the next button is disabled (indicating the last page)
    if next_button is None:
        break
    else:
        # Get the URL for the next page
        next_url = next_button['href']
        # Construct the full URL using urljoin
        url = 'https://www.zoopla.co.uk/for-sale/property/london/?q=London&search_source=home&pn={}'.format(count)
        url = urljoin(url, next_url)
        # Make a request through Scrapfly to bypass anti-scraping measures
        response = client.scrape(ScrapeConfig(url, country="GB", asp=True))
        html = response.content

        soup = BeautifulSoup(html, "lxml")
        prop = re.findall(r"listing_\d+", soup.prettify())
        count+=1
        print(url)
        # Pause execution for a few seconds
        time.sleep(5)

# Display the scraped data
sale_zoopla

# %%
zoopla_sale = sale_zoopla.copy()
sale_zoopla.to_csv('zoopla_sale.csv')

# %% [markdown]
# #### For rent

# %%
# Set up Scrapfly credentials
API_KEY = "API KEY"
client = ScrapflyClient(API_KEY)
count = 1
# Set the initial URL
url = 'https://www.zoopla.co.uk/to-rent/property/london/?q=London&search_source=home&pn={}'.format(count)
response = client.scrape(ScrapeConfig(url, country="GB", asp=True))
html = response.content
soup = BeautifulSoup(html, "lxml")
prop = re.findall(r"listing_\d+", soup.prettify())

# Create a DataFrame to store scraped data
rent_zoopla = pd.DataFrame(columns=['Address', 'Price', 'Description', 'Agent_name', 'Agent_website',
                                    'Agent_contact', 'Listing_url', 'No_of_Bedroom', 'No_of_Bathroom',
                                    'No_of_livingroom'])

# Loop to scrape property details from multiple pages
while True:
    # Extract details from each property element
    for i in prop:
        details = {}
        for j in soup.find('div', id=i, class_='f0xnzq2'):
            # Extract property details using CSS selectors
            Address = j.find('h3', class_="_1ankud52 _1ftx2fq9")
            if Address is not None:
                details['Address'] = Address.text.strip()

            # Extract price using CSS selector
            Price = j.find('div', class_="_170k6631")
            if Price is not None:
                details['Price'] = Price.text.strip()

            # Extract description using CSS selector
            description = j.find('h2', class_="_1ankud51 _1ftx2fq8")
            if description is not None:
                details['Description'] = description.text.strip()
            # Extract agent name and website using CSS selector
            Agent_name = j.find('div', class_='fas4ee0')
            if Agent_name is not None:
                img_tag = Agent_name.find('img', class_='_12bxhf70')
            if img_tag is not None:
                details['Agent_name'] = img_tag.get('alt')


            # Extract agent name and website using CSS selector
            Agent_website = j.find('div', class_='fas4ee0')
            if Agent_website is not None:
                details['Agent_website'] = urljoin(url, Agent_website.a['href'])

            # Extract agent contact using CSS selector
            Agent_contact = j.find('a', {'aria-label': 'Contact agent'})
            if Agent_contact is not None:
                details['Agent_contact'] = urljoin(url, Agent_contact['href'])

            # Extract listing URL using CSS selector
            Listing_url = j.find('a', class_='_1maljyt1')
            if Listing_url is not None:
                details['Listing_url'] = urljoin(url, Listing_url['href'])

            # Extract bedroom, bathroom, and living room information using CSS selector
            data = {'Bedrooms': np.NaN, 'Bathrooms': np.NaN, 'Living rooms': np.NaN}
            for item in j.find_all('li', class_='_3fbafd1'):
                value_element = re.search(r"\d+", item.text.strip()).group(0)
                label_element = item.find('span').text.strip()
                if label_element and value_element:
                    label = label_element
                    value = value_element
                    data[label] = value

            details['No_of_Bedroom'] = data['Bedrooms']
            details['No_of_Bathroom'] = data['Bathrooms']
            details['No_of_livingroom'] = data['Living rooms']

            # Create a DataFrame with the property details
            details = pd.DataFrame(details, index=[0])
            rent_zoopla = pd.concat([rent_zoopla, details], ignore_index=True)

    # Find the next page button element
    next_button = soup.find('a', class_="x8jo560 x8jo563 x8jo56a _1ftx2fq8", attrs={"aria-disabled": "false"})

    # Check if the next button is disabled (indicating the last page)
    if next_button is None:
        break
    else:
        # Get the URL for the next page
        next_url = next_button['href']
        # Construct the full URL using urljoin
        url = 'https://www.zoopla.co.uk/to-rent/property/london/?q=London&search_source=home&pn={}'.format(count)
        url = urljoin(url, next_url)
        # Make a request through Scrapfly to bypass anti-scraping measures
        response = client.scrape(ScrapeConfig(url, country="GB", asp=True))
        html = response.content

        soup = BeautifulSoup(html, "lxml")
        prop = re.findall(r"listing_\d+", soup.prettify())
        count+=1
        print(url)
        # Pause execution for a few seconds
        time.sleep(5)

# Display the scraped data
rent_zoopla

# %%
zoopla_rent = rent_zoopla.copy()
rent_zoopla.to_csv('zoopla_rent.csv')

# %% [markdown]
# [GoToTop](#top)
#
# <p id='otm'></p>
#
# ## Webscraping onthemarket.co.uk

# %%
options = webdriver.ChromeOptions()
#options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3')
service = Service('C:\\Users\\Simplicity\\chromedriver_win32')
driver = webdriver.Chrome(service=service, options=options)

# %% [markdown]
# ### For sale

# %%
url = 'https://www.onthemarket.com/for-sale/'
driver.get(url)
time.sleep(10)

# %%
# Enter search query
search_box = driver.find_element(By.ID,'search-location-sale')
search_box.clear()
search_box.send_keys('London')
search_box.send_keys(Keys.RETURN)
time.sleep(5)

# %%
# Create an empty DataFrame for OnTheMarket property data
otm_data = pd.DataFrame(columns=['Price', 'Address', 'description', 'No_of_bedroom', 'No_of_bathroom',
                                 'listing_url', 'agent_website', 'agent_name'])

# Loop to scrape property details from multiple pages
while True:
    # Scroll to the bottom of the page
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
    # Pause execution for 2 seconds
    time.sleep(2)
    
    # Get the page source and create a BeautifulSoup object
    html = driver.page_source
    soup = BeautifulSoup(html, "lxml")
    
    # Find all property elements on the page
    prop = re.findall(r"result-\d{3,}", soup.prettify())
    
    # Extract details from each property element
    for j in prop:
        otm = {}
        for i in soup.find('div', id=j):
            # Extract price using CSS selector
            price = i.find('div', class_='otm-Price')
            if price is not None:
                otm['Price'] = [price.find('a', class_='text-denim price mb-0 font-bold').text.strip()]
            
            # Extract address using CSS selector
            address = i.find('span', class_='address')
            if address is not None:
                otm['Address'] = [address.text.strip()]
            
            # Extract description using CSS selector
            description = i.find('span', class_='title')
            if description is not None:
                otm['description'] = [description.text.strip()]
            
            # Extract number of bedrooms and bathrooms using CSS selector
            bedroom_div = i.find('div', class_='otm-BedBathCount flex items-center')
            if bedroom_div is not None:
                otm['No_of_bedroom'] = [bedroom_div.find_all('div')[0].text]
                otm['No_of_bathroom'] = [bedroom_div.find_all('div')[1].text]
         
            # Extract listing URL using CSS selector
            listing_url = i.find('div', class_='agent-logo')
            if listing_url is not None:
                url = re.search(r"([a-zA-Z]+[\W]+[a-zA-Z\.]+)", url).group()
                otm['listing_url'] = [url + listing_url.find('a')['href']]
            
            # Extract agent website and name using CSS selector
            agent_website = i.find('div', class_='agent-logo')
            if agent_website is not None:
                agent_website = agent_website.find_next_sibling('div')
                otm['agent_website'] = [re.search(r"([a-zA-Z]+[\W]+[a-zA-Z\.]+)", url).group() + agent_website.find('small').a['href']]
                otm['agent_name'] = [agent_website.find('small').a.text]
                
        # Create a DataFrame with the property details
        otm = pd.DataFrame(otm)
        otm_data = pd.concat([otm_data, otm], ignore_index=True)
    
    try: 
        # Find the next button for pagination
        next_button = driver.find_element(By.CSS_SELECTOR, 'a[title="Next page"]')
        button_class = next_button.find_element(By.CSS_SELECTOR, 'button.otm-Button')
        
        # Check if the next button is disabled (indicating the last page)
        if driver.execute_script("return arguments[0].disabled;", button_class) == True:
            break
        else:
            # Scroll to the next button and click it
            driver.execute_script("arguments[0].scrollIntoView();", next_button)
            driver.execute_script("arguments[0].click();", button_class)
        
        # Pause execution for 10 seconds
        time.sleep(10)
    
    except NoSuchElementException:
        break

# Close the WebDriver
driver.quit()

# Display the first few rows of the OnTheMarket property data DataFrame
otm_data.head()

# %%
otm_data

# %%
otm_sale = otm_data.copy()
otm_data.to_csv('otm_sale.csv')

# %% [markdown]
# ### For rent

# %%
options = webdriver.ChromeOptions()
#options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3')
service = Service('C:\\Users\\Simplicity\\chromedriver_win32')
driver = webdriver.Chrome(service=service, options=options)

# %%
url = 'https://www.onthemarket.com/to-rent/'
driver.get(url)
time.sleep(5)

# %%
# Enter search query
search_box = driver.find_element(By.CLASS_NAME,'landing-search-input')
search_box.clear()
search_box.send_keys('London')
search_box.send_keys(Keys.RETURN)
time.sleep(5)

# %%
# Create an empty DataFrame for storing OnTheMarket property data
otm_data = pd.DataFrame(columns=['Price', 'Address', 'description', 'No_of_bedroom', 'No_of_bathroom',
                                 'listing_url', 'agent_website', 'agent_name'])

# Loop to scrape property details from multiple pages
while True:
    # Scroll to the bottom of the page
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    
    # Pause execution for 2 seconds
    time.sleep(2)
    
    # Get the page source and create a BeautifulSoup object
    html = driver.page_source
    soup = BeautifulSoup(html, "lxml")
    
    # Find all property elements on the page
    prop = re.findall(r"result-\d{3,}", soup.prettify())
    
    # Extract details from each property element
    for j in prop:
        otm = {}
        for i in soup.find('div', id=j):
            # Extract price using CSS selector
            price = i.find('div', class_='otm-Price')
            if price is not None:
                otm['Price'] = [price.find('a', class_='text-denim price mb-0 font-bold').text.strip()]
            
            # Extract address using CSS selector
            address = i.find('span', class_='address')
            if address is not None:
                otm['Address'] = [address.text.strip()]
            
            # Extract description using CSS selector
            description = i.find('span', class_='title')
            if description is not None:
                otm['description'] = [description.text.strip()]
            
            # Extract number of bedrooms and bathrooms using CSS selector
            bedroom_div = i.find('div', class_='otm-BedBathCount flex items-center')
            if bedroom_div is not None:
                otm['No_of_bedroom'] = [bedroom_div.find_all('div')[0].text]
                otm['No_of_bathroom'] = [bedroom_div.find_all('div')[1].text]
         
            # Extract listing URL using CSS selector
            listing_url = i.find('div', class_='agent-logo')
            if listing_url is not None:
                url = re.search(r"([a-zA-Z]+[\W]+[a-zA-Z\.]+)", url).group()
                otm['listing_url'] = [url + listing_url.find('a')['href']]
            
            # Extract agent website and name using CSS selector
            agent_website = i.find('div', class_='agent-logo')
            if agent_website is not None:
                agent_website = agent_website.find_next_sibling('div')
                otm['agent_website'] = [re.search(r"([a-zA-Z]+[\W]+[a-zA-Z\.]+)", url).group() + agent_website.find('small').a['href']]
                otm['agent_name'] = [agent_website.find('small').a.text]
                
        # Create a DataFrame with the property details
        otm = pd.DataFrame(otm)
        
        # Concatenate the property data DataFrame to the main DataFrame
        otm_data = pd.concat([otm_data, otm], ignore_index=True)
        
    try:
        # Find the next button for pagination
        next_button = driver.find_element(By.CSS_SELECTOR, 'a[title="Next page"]')
        button_class = next_button.find_element(By.CSS_SELECTOR, 'button.otm-Button')
        driver.execute_script("arguments[0].click();", button_class)
    
    except NoSuchElementException:
        # Break the loop if the next button is not found (indicating the last page)
        break

# Close the WebDriver
driver.quit()

# Display the first few rows of the OnTheMarket property data DataFrame
otm_data.head()

# %%
otm_data

# %%
otm_rent = otm_data.copy()
otm_data.to_csv('otm_rent.csv')

# %% [markdown]
# [GoToTop](#top)
#
# <p id='wrangle'></p>
#
# ## DATA WRANGLING

# %% [markdown]
# All data collected will be imported for Data cleaning

# %% [markdown]
# ## London district Postcode data

# %%
postcode_dist = pd.read_csv('postcode.csv')
post_list = postcode_dist['Postcode district'].tolist()
postcode_dist.head()
# Out:
#   Postcode district                                        Local Areas  \
# 0               BR1                          Bromley, Bickley, Downham
# 1               BR2         Bickley, Hayes, Bromley Common, Shortlands
# 2               BR3  Beckenham, Eden Park, Elmers End, Park Langley...
# 3               BR4                                       West Wickham
# 4               BR5                Orpington, St Mary Cray, Petts Wood
#
#    Borough
# 0  Bromley
# 1  Bromley
# 2  Bromley
# 3  Bromley
# 4  Bromley

# %% [markdown]
# <p id='wrightmove'></p>
#
# ### RIGHTMOVE

# %%
#rightmove data
rightmove_sale = pd.read_csv('rightmove_sale.csv')
rightmove_rent = pd.read_csv('rightmove_rent.csv')

# %%
rightmove_sale.head()
# Out:
#                                        Address       Type        Price  \
# 0                        Glyn Road, London, E5   Terraced   £1,100,000
# 1                 One Hyde Park, Knightsbridge  Apartment  £60,000,000
# 2                 Lygon Place, Belgravia, SW1W      House  £45,000,000
# 3  Mayfair Freehold House, Park Lane Area, W1K      House  £45,000,000
# 4                  Pitt Street, Kensington, W8      House  £44,000,000
#
#   No_of_bedroom No_of_bathroom  \
# 0    3 bedrooms     1 bathroom
# 1    5 bedrooms    5 bathrooms
# 2    7 bedrooms    9 bathrooms
# 3   12 bedrooms   18 bathrooms
# 4    6 bedrooms    5 bathrooms
#
#                                          description  \
# 0  A truly unique and stunning three bedroom peri...
# 1  An exceptional exclusive five bedroom apartmen...
# 2  Ref. LOB0798 - Set behind a gated Belgravia dr...
# 3  This stunning 12 bedroom (including 3 staff be...
# 4  Ref. LOB0625 - This striking and unique house ...
#
#                                   Agent_name  \
# 0                  Stirling Ackroyd, Clapton
# 1                       The Cloister, London
# 2    Beauchamp Estates Ltd, Mayfair - Resale
# 3  Luxury Living Homes International, London
# 4    Beauchamp Estates Ltd, Mayfair - Resale
#
#                                        Agent_website  \
# 0  https://www.rightmove.co.uk/estate-agents/agen...
# 1  https://www.rightmove.co.uk/estate-agents/agen...
# 2  https://www.rightmove.co.uk/estate-agents/agen...
# 3  https://www.rightmove.co.uk/estate-agents/agen...
# 4  https://www.rightmove.co.uk/estate-agents/agen...
#
#                                        Agent_contact  \
# 0  https://www.rightmove.co.uk/property-for-sale/...
# 1  https://www.rightmove.co.uk/property-for-sale/...
# 2  https://www.rightmove.co.uk/property-for-sale/...
# 3  https://www.rightmove.co.uk/property-for-sale/...
# 4  https://www.rightmove.co.uk/property-for-sale/...
#
#                                          Listing_url
# 0  https://www.rightmove.co.uk/properties/1352692...
# 1  https://www.rightmove.co.uk/properties/1301776...
# 2  https://www.rightmove.co.uk/properties/1293029...
# 3  https://www.rightmove.co.uk/properties/1303065...
# 4  https://www.rightmove.co.uk/properties/1318567...

# %%
rightmove_sale.shape
# Out:
# (1050, 10)

# %%
rightmove_sale.dtypes
# Out:
# Address           object
# Type              object
# Price             object
# No_of_bedroom     object
# No_of_bathroom    object
# description       object
# Agent_name        object
# Agent_website     object
# Agent_contact     object
# Listing_url       object
# dtype: object

# %%
rightmove_sale.Price = rightmove_sale.Price.str.extract('([\d{1,}]+)')
rightmove_sale.Price = rightmove_sale.Price.str.replace(',','')
rightmove_sale = rightmove_sale.dropna(subset = ['Price','No_of_bedroom','No_of_bathroom'],axis = 0)
rightmove_sale.Price = rightmove_sale.Price.astype('int')
rightmove_sale['Transaction_type'] = np.repeat('sales',rightmove_sale.shape[0])
rightmove_sale.rename(columns = {'Type':'Property_type'},inplace = True)
rightmove_sale['No_of_bedroom'] =  rightmove_sale['No_of_bedroom'].str.extract('(\d{1,})').astype('int')
rightmove_sale['No_of_bathroom'] =  rightmove_sale['No_of_bathroom'].str.extract('(\d{1,})').astype('int')

# %%
#Checking for duplicates
rightmove_sale.duplicated().sum()
# Out:
# 0

# %%
#resetting index 
rightmove_sale.reset_index(drop = True,inplace = True)

# %%
rightmove_sale.head()
# Out:
#                                        Address Property_type     Price  \
# 0                        Glyn Road, London, E5      Terraced   1100000
# 1                 One Hyde Park, Knightsbridge     Apartment  60000000
# 2                 Lygon Place, Belgravia, SW1W         House  45000000
# 3  Mayfair Freehold House, Park Lane Area, W1K         House  45000000
# 4                  Pitt Street, Kensington, W8         House  44000000
#
#    No_of_bedroom  No_of_bathroom  \
# 0              3               1
# 1              5               5
# 2              7               9
# 3             12              18
# 4              6               5
#
#                                          description  \
# 0  A truly unique and stunning three bedroom peri...
# 1  An exceptional exclusive five bedroom apartmen...
# 2  Ref. LOB0798 - Set behind a gated Belgravia dr...
# 3  This stunning 12 bedroom (including 3 staff be...
# 4  Ref. LOB0625 - This striking and unique house ...
#
#                                   Agent_name  \
# 0                  Stirling Ackroyd, Clapton
# 1                       The Cloister, London
# 2    Beauchamp Estates Ltd, Mayfair - Resale
# 3  Luxury Living Homes International, London
# 4    Beauchamp Estates Ltd, Mayfair - Resale
#
#                                        Agent_website  \
# 0  https://www.rightmove.co.uk/estate-agents/agen...
# 1  https://www.rightmove.co.uk/estate-agents/agen...
# 2  https://www.rightmove.co.uk/estate-agents/agen...
# 3  https://www.rightmove.co.uk/estate-agents/agen...
# 4  https://www.rightmove.co.uk/estate-agents/agen...
#
#                                        Agent_contact  \
# 0  https://www.rightmove.co.uk/property-for-sale/...
# 1  https://www.rightmove.co.uk/property-for-sale/...
# 2  https://www.rightmove.co.uk/property-for-sale/...
# 3  https://www.rightmove.co.uk/property-for-sale/...
# 4  https://www.rightmove.co.uk/property-for-sale/...
#
#                                          Listing_url Transaction_type
# 0  https://www.rightmove.co.uk/properties/1352692...            sales
# 1  https://www.rightmove.co.uk/properties/1301776...            sales
# 2  https://www.rightmove.co.uk/properties/1293029...            sales
# 3  https://www.rightmove.co.uk/properties/1303065...            sales
# 4  https://www.rightmove.co.uk/properties/1318567...            sales

# %%
# Extracting out the district Postcode present in the Address by using the list of District Postcode in london.
for i,j in enumerate(rightmove_sale['Address']):
    for k in post_list:
        if k in rightmove_sale['Address'][i]:
            rightmove_sale.loc[i,'Postcode_district'] = k
            break
        else:
            rightmove_sale.loc[i,'Postcode_district'] = np.NaN

# %%
rightmove_sale
# Out:
#                                                Address Property_type  \
# 0                                Glyn Road, London, E5      Terraced
# 1                         One Hyde Park, Knightsbridge     Apartment
# 2                         Lygon Place, Belgravia, SW1W         House
# 3          Mayfair Freehold House, Park Lane Area, W1K         House
# 4                          Pitt Street, Kensington, W8         House
# ..                                                 ...           ...
# 984          William Mews, Knightsbridge, London, SW1X      Terraced
# 985                        Davies Street, Mayfair, W1K          Flat
# 986                      Dunraven Street, Mayfair, W1K     Apartment
# 987  Scarsdale Studios, 21a Stratford Road, Kensing...         House
# 988                           Uphill Road, London, NW7      Detached
#
#         Price  No_of_bedroom  No_of_bathroom  \
# 0     1100000              3               1
# 1    60000000              5               5
# 2    45000000              7               9
# 3    45000000             12              18
# 4    44000000              6               5
# ..        ...            ...             ...
# 984   5950000              4               4
# 985   5950000              3               3
# 986   5950000              2               2
# 987   5950000              4               3
# 988   5950000              6               5
#
#                                            description  \
# 0    A truly unique and stunning three bedroom peri...
# 1    An exceptional exclusive five bedroom apartmen...
# 2    Ref. LOB0798 - Set behind a gated Belgravia dr...
# 3    This stunning 12 bedroom (including 3 staff be...
# 4    Ref. LOB0625 - This striking and unique house ...
# ..                                                 ...
# 984            A fabulous low built four bedroom house
# 985  Ref. LOB0838 - A contemporary sixth-floor apar...
# 986  A beautiful and stylish penthouse apartment wh...
# 987  Unique four bedroom house in a former artist’s...
# 988  United Kingdom Sotheby's International Realty ...
#
#                                     Agent_name  \
# 0                    Stirling Ackroyd, Clapton
# 1                         The Cloister, London
# 2      Beauchamp Estates Ltd, Mayfair - Resale
# 3    Luxury Living Homes International, London
# 4      Beauchamp Estates Ltd, Mayfair - Resale
# ..                                         ...
# 984                   Russell Simpson, Chelsea
# 985    Beauchamp Estates Ltd, Mayfair - Resale
# 986    Sandersons, Holland Park & Notting Hill
# 987                Russell Simpson, Kensington
# 988     Sotheby's International Realty, London
#
#                                          Agent_website  \
# 0    https://www.rightmove.co.uk/estate-agents/agen...
# 1    https://www.rightmove.co.uk/estate-agents/agen...
# 2    https://www.rightmove.co.uk/estate-agents/agen...
# 3    https://www.rightmove.co.uk/estate-agents/agen...
# 4    https://www.rightmove.co.uk/estate-agents/agen...
# ..                                                 ...
# 984  https://www.rightmove.co.uk/estate-agents/agen...
# 985  https://www.rightmove.co.uk/estate-agents/agen...
# 986  https://www.rightmove.co.uk/estate-agents/agen...
# 987  https://www.rightmove.co.uk/estate-agents/agen...
# 988  https://www.rightmove.co.uk/estate-agents/agen...
#
#                                          Agent_contact  \
# 0    https://www.rightmove.co.uk/property-for-sale/...
# 1    https://www.rightmove.co.uk/property-for-sale/...
# 2    https://www.rightmove.co.uk/property-for-sale/...
# 3    https://www.rightmove.co.uk/property-for-sale/...
# 4    https://www.rightmove.co.uk/property-for-sale/...
# ..                                                 ...
# 984  https://www.rightmove.co.uk/property-for-sale/...
# 985  https://www.rightmove.co.uk/property-for-sale/...
# 986  https://www.rightmove.co.uk/property-for-sale/...
# 987  https://www.rightmove.co.uk/property-for-sale/...
# 988  https://www.rightmove.co.uk/property-for-sale/...
#
#                                            Listing_url Transaction_type  \
# 0    https://www.rightmove.co.uk/properties/1352692...            sales
# 1    https://www.rightmove.co.uk/properties/1301776...            sales
# 2    https://www.rightmove.co.uk/properties/1293029...            sales
# 3    https://www.rightmove.co.uk/properties/1303065...            sales
# 4    https://www.rightmove.co.uk/properties/1318567...            sales
# ..                                                 ...              ...
# 984  https://www.rightmove.co.uk/properties/1327277...            sales
# 985  https://www.rightmove.co.uk/properties/1326496...            sales
# 986  https://www.rightmove.co.uk/properties/8486177...            sales
# 987  https://www.rightmove.co.uk/properties/1341741...            sales
# 988  https://www.rightmove.co.uk/properties/1345028...            sales
#
#     Postcode_district
# 0                  E5
# 1                 NaN
# 2                SW1W
# 3                 W1K
# 4                  W8
# ..                ...
# 984              SW1X
# 985               W1K
# 986               W1K
# 987                W8
# 988               NW7
#
# [989 rows x 12 columns]

# %%
#Filling null values with None
rightmove_sale['Postcode_district'].fillna('None',inplace = True)

# %%
#Making a copy of the District code yet to be gotten.
rightmove_sale_copy = rightmove_sale.query('Postcode_district == "None"')

# %%
#Dropping the index where we have district code to be null
rightmove_sale.drop(rightmove_sale_copy.index,inplace = True)

# %%
#Resetting index of the copied data
rightmove_sale_copy.reset_index(drop = True,inplace = True)

# %%
rightmove_sale.query('Postcode_district == "None"')
# Out:
# Empty DataFrame
# Columns: [Address, Property_type, Price, No_of_bedroom, No_of_bathroom, description, Agent_name, Agent_website, Agent_contact, Listing_url, Transaction_type, Postcode_district]
# Index: []

# %%
#Using geolocator to get other district postcodes
geolocator = Nominatim(user_agent="postcode_extractor")
for i, j in enumerate(rightmove_sale_copy['Address']):
    location = geolocator.geocode(rightmove_sale_copy['Address'][i], country_codes="GB", addressdetails=True, timeout=10)
    if location is not None:
        # Extract the postcode from the location address details
        postcode = location.raw.get('address', {}).get('postcode')
        if postcode:
            # Extract the district postcode from the full postcode
            rightmove_sale_copy.loc[i, 'Postcode_district'] = postcode.split()[0]
        else:
            # If postcode is not available, set district postcode as 'None'
            rightmove_sale_copy.loc[i, 'Postcode_district'] = 'None'
    else:
        # If location is not found, set district postcode as 'None'
        rightmove_sale_copy.loc[i, 'Postcode_district'] = 'None'

# %%
rightmove_sale = rightmove_sale.query('Postcode_district != "None"')

# %%
#Checking district code which are yet to be gotten
righmove_sale_copy = rightmove_sale_copy.query('Postcode_district != "None"')

# %%
rightmove_sale_copy.query('Postcode_district != "None"')
# Out:
#                               Address Property_type     Price  No_of_bedroom  \
# 0        One Hyde Park, Knightsbridge     Apartment  60000000              5
# 1           Royal Westminster, London      Detached  35000000              7
# 2                South Street, London      Terraced  35000000              5
# 3        One Hyde Park, Knightsbridge     Apartment  30000000              3
# 5                       Culross House         House  26950000              5
# ..                                ...           ...       ...            ...
# 183        Kew Bridge Road, Brentford     Apartment    435000              1
# 184              Trevor Place, London      Terraced   5999950              4
# 186              Carnation Way,London     Apartment   5960000              4
# 187            Uphill Road, Mill Hill      Detached   5950000              6
# 188  199 Knightsbridge, Knightsbridge     Apartment   5950000              2
#
#      No_of_bathroom                                        description  \
# 0                 5  An exceptional exclusive five bedroom apartmen...
# 1                 5  A very rare find this luxurious circa 11000 SQ...
# 2                 6  An elegant stone-dressed, red-brick, five-stor...
# 3                 3  The Cloister are pleased to present this stunn...
# 5                 6  A newly constructed Mayfair Mansion, designed ...
# ..              ...                                                ...
# 183               1  Luxury apartment - WITH OWN SECURE GATED ALLOC...
# 184               3  Trevor Place is a stunning freehold property i...
# 186               4  Luxury Living Homes is pleased to present an i...
# 187               5  A beautifully designed Tudor style home in the...
# 188               2  Set in this contemporary building in the heart...
#
#                                     Agent_name  \
# 0                         The Cloister, London
# 1    Luxury Living Homes International, London
# 2                           Wetherell, Mayfair
# 3                         The Cloister, London
# 5                         London House, London
# ..                                         ...
# 183                   Barnard Marcus, Chiswick
# 184                    Chatterton Rees, London
# 186  Luxury Living Homes International, London
# 187                   Real Estates, Totteridge
# 188                       The Cloister, London
#
#                                          Agent_website  \
# 0    https://www.rightmove.co.uk/estate-agents/agen...
# 1    https://www.rightmove.co.uk/estate-agents/agen...
# 2    https://www.rightmove.co.uk/estate-agents/agen...
# 3    https://www.rightmove.co.uk/estate-agents/agen...
# 5    https://www.rightmove.co.uk/estate-agents/agen...
# ..                                                 ...
# 183  https://www.rightmove.co.uk/estate-agents/agen...
# 184  https://www.rightmove.co.uk/estate-agents/agen...
# 186  https://www.rightmove.co.uk/estate-agents/agen...
# 187  https://www.rightmove.co.uk/estate-agents/agen...
# 188  https://www.rightmove.co.uk/estate-agents/agen...
#
#                                          Agent_contact  \
# 0    https://www.rightmove.co.uk/property-for-sale/...
# 1    https://www.rightmove.co.uk/property-for-sale/...
# 2    https://www.rightmove.co.uk/property-for-sale/...
# 3    https://www.rightmove.co.uk/property-for-sale/...
# 5    https://www.rightmove.co.uk/property-for-sale/...
# ..                                                 ...
# 183  https://www.rightmove.co.uk/property-for-sale/...
# 184  https://www.rightmove.co.uk/property-for-sale/...
# 186  https://www.rightmove.co.uk/property-for-sale/...
# 187  https://www.rightmove.co.uk/property-for-sale/...
# 188  https://www.rightmove.co.uk/property-for-sale/...
#
#                                            Listing_url Transaction_type  \
# 0    https://www.rightmove.co.uk/properties/1301776...            sales
# 1    https://www.rightmove.co.uk/properties/1344499...            sales
# 2    https://www.rightmove.co.uk/properties/1281503...            sales
# 3    https://www.rightmove.co.uk/properties/1343810...            sales
# 5    https://www.rightmove.co.uk/properties/1326125...            sales
# ..                                                 ...              ...
# 183  https://www.rightmove.co.uk/properties/1343518...            sales
# 184  https://www.rightmove.co.uk/properties/1315975...            sales
# 186  https://www.rightmove.co.uk/properties/1334994...            sales
# 187  https://www.rightmove.co.uk/properties/1340668...            sales
# 188  https://www.rightmove.co.uk/properties/1282441...            sales
#
#     Postcode_district
# 0                SW1X
# 1                SW1Y
# 2                TN16
# 3                SW1X
# 5                 W10
# ..                ...
# 183                W4
# 184               SW7
# 186               SW8
# 187               NW7
# 188               SW7
#
# [146 rows x 12 columns]

# %%
rightmove_sale.dtypes
# Out:
# Address              object
# Property_type        object
# Price                 int32
# No_of_bedroom         int32
# No_of_bathroom        int32
# description          object
# Agent_name           object
# Agent_website        object
# Agent_contact        object
# Listing_url          object
# Transaction_type     object
# Postcode_district    object
# dtype: object

# %%
#Getting the final data.
rightmove_sale = pd.concat([rightmove_sale,rightmove_sale_copy],ignore_index = True)

# %%
rightmove_sale.rename(columns = {'No_of_bedroom':'No_of_Bedroom','No_of_bathroom':'No_of_Bathroom',
                                'description':'Description'},inplace = True)

# %%
rightmove_sale
# Out:
#                                          Address Property_type     Price  \
# 0                          Glyn Road, London, E5      Terraced   1100000
# 1                   Lygon Place, Belgravia, SW1W         House  45000000
# 2    Mayfair Freehold House, Park Lane Area, W1K         House  45000000
# 3                    Pitt Street, Kensington, W8         House  44000000
# 4                        Pitt Street, London, W8      Detached  44000000
# ..                                           ...           ...       ...
# 984                         Trevor Place, London      Terraced   5999950
# 985                          Elm Walk, Hampstead      Detached   5995999
# 986                         Carnation Way,London     Apartment   5960000
# 987                       Uphill Road, Mill Hill      Detached   5950000
# 988             199 Knightsbridge, Knightsbridge     Apartment   5950000
#
#      No_of_Bedroom  No_of_Bathroom  \
# 0                3               1
# 1                7               9
# 2               12              18
# 3                6               5
# 4                7               5
# ..             ...             ...
# 984              4               3
# 985              6               4
# 986              4               4
# 987              6               5
# 988              2               2
#
#                                            Description  \
# 0    A truly unique and stunning three bedroom peri...
# 1    Ref. LOB0798 - Set behind a gated Belgravia dr...
# 2    This stunning 12 bedroom (including 3 staff be...
# 3    Ref. LOB0625 - This striking and unique house ...
# 4    A rare opportunity to own this unique, contemp...
# ..                                                 ...
# 984  Trevor Place is a stunning freehold property i...
# 985  An imposing detached double fronted house offe...
# 986  Luxury Living Homes is pleased to present an i...
# 987  A beautifully designed Tudor style home in the...
# 988  Set in this contemporary building in the heart...
#
#                                     Agent_name  \
# 0                    Stirling Ackroyd, Clapton
# 1      Beauchamp Estates Ltd, Mayfair - Resale
# 2    Luxury Living Homes International, London
# 3      Beauchamp Estates Ltd, Mayfair - Resale
# 4                          Savills, Kensington
# ..                                         ...
# 984                    Chatterton Rees, London
# 985   Goldschmidt & Howland, Hampstead - Sales
# 986  Luxury Living Homes International, London
# 987                   Real Estates, Totteridge
# 988                       The Cloister, London
#
#                                          Agent_website  \
# 0    https://www.rightmove.co.uk/estate-agents/agen...
# 1    https://www.rightmove.co.uk/estate-agents/agen...
# 2    https://www.rightmove.co.uk/estate-agents/agen...
# 3    https://www.rightmove.co.uk/estate-agents/agen...
# 4    https://www.rightmove.co.uk/estate-agents/agen...
# ..                                                 ...
# 984  https://www.rightmove.co.uk/estate-agents/agen...
# 985  https://www.rightmove.co.uk/estate-agents/agen...
# 986  https://www.rightmove.co.uk/estate-agents/agen...
# 987  https://www.rightmove.co.uk/estate-agents/agen...
# 988  https://www.rightmove.co.uk/estate-agents/agen...
#
#                                          Agent_contact  \
# 0    https://www.rightmove.co.uk/property-for-sale/...
# 1    https://www.rightmove.co.uk/property-for-sale/...
# 2    https://www.rightmove.co.uk/property-for-sale/...
# 3    https://www.rightmove.co.uk/property-for-sale/...
# 4    https://www.rightmove.co.uk/property-for-sale/...
# ..                                                 ...
# 984  https://www.rightmove.co.uk/property-for-sale/...
# 985  https://www.rightmove.co.uk/property-for-sale/...
# 986  https://www.rightmove.co.uk/property-for-sale/...
# 987  https://www.rightmove.co.uk/property-for-sale/...
# 988  https://www.rightmove.co.uk/property-for-sale/...
#
#                                            Listing_url Transaction_type  \
# 0    https://www.rightmove.co.uk/properties/1352692...            sales
# 1    https://www.rightmove.co.uk/properties/1293029...            sales
# 2    https://www.rightmove.co.uk/properties/1303065...            sales
# 3    https://www.rightmove.co.uk/properties/1318567...            sales
# 4    https://www.rightmove.co.uk/properties/1318464...            sales
# ..                                                 ...              ...
# 984  https://www.rightmove.co.uk/properties/1315975...            sales
# 985  https://www.rightmove.co.uk/properties/1281999...            sales
# 986  https://www.rightmove.co.uk/properties/1334994...            sales
# 987  https://www.rightmove.co.uk/properties/1340668...            sales
# 988  https://www.rightmove.co.uk/properties/1282441...            sales
#
#     Postcode_district
# 0                  E5
# 1                SW1W
# 2                 W1K
# 3                  W8
# 4                  W8
# ..                ...
# 984               SW7
# 985              None
# 986               SW8
# 987               NW7
# 988               SW7
#
# [989 rows x 12 columns]

# %%
rightmove_sale.to_csv('rightmove_sale_master.csv',index = False)

# %%
rightmove_rent.head()
# Out:
#                                     Address            Type       Price  \
# 0  Blythwood Road, Stroud Green, London, N4  End of Terrace  £5,250 pcm
# 1           Kingfisher Heights, London, E16            Flat  £1,850 pcm
# 2              Torriano Avenue, London, NW5            Flat  £4,500 pcm
# 3               Ringstead Road, London, SE6            Flat  £1,460 pcm
# 4                    A Millway, London, NW7      Maisonette  £1,800 pcm
#
#     Price_pw No_of_bedroom No_of_bathroom  \
# 0  £1,212 pw    5 bedrooms    2 bathrooms
# 1    £427 pw     1 bedroom     1 bathroom
# 2  £1,038 pw     1 bedroom     1 bathroom
# 3    £337 pw     1 bedroom     1 bathroom
# 4    £415 pw    2 bedrooms     1 bathroom
#
#                                          description  \
# 0  NO DEPOSIT OPTION AVAILABLE. Lovely five bedro...
# 1  Property Description: This beautiful one bedro...
# 2  A wonderfully stylish 1 bedroom apartment loca...
# 3  We are proud to offer this delightful 1 bedroo...
# 4  We are proud to offer this delightful 2 bedroo...
#
#                    Agent_name  \
# 0  Martyn Gerrard, Crouch End
# 1            OpenRent, London
# 2            OpenRent, London
# 3            OpenRent, London
# 4            OpenRent, London
#
#                                        Agent_website  \
# 0  https://www.rightmove.co.uk/estate-agents/agen...
# 1  https://www.rightmove.co.uk/estate-agents/agen...
# 2  https://www.rightmove.co.uk/estate-agents/agen...
# 3  https://www.rightmove.co.uk/estate-agents/agen...
# 4  https://www.rightmove.co.uk/estate-agents/agen...
#
#                                        Agent_contact  \
# 0  https://www.rightmove.co.uk/property-to-rent/c...
# 1  https://www.rightmove.co.uk/property-to-rent/c...
# 2  https://www.rightmove.co.uk/property-to-rent/c...
# 3  https://www.rightmove.co.uk/property-to-rent/c...
# 4  https://www.rightmove.co.uk/property-to-rent/c...
#
#                                          Listing_url
# 0  https://www.rightmove.co.uk/properties/1352645...
# 1  https://www.rightmove.co.uk/properties/1354085...
# 2  https://www.rightmove.co.uk/properties/1354085...
# 3  https://www.rightmove.co.uk/properties/1354085...
# 4  https://www.rightmove.co.uk/properties/1354085...

# %%
rightmove_rent = rightmove_rent.dropna(subset = ['Price','Price_pw','No_of_bedroom','No_of_bathroom'],axis = 0)
cols = ['Price','Price_pw']
for i in cols:
    rightmove_rent[i] = rightmove_rent[i].str.extract('([\d{1,}]+)')
    rightmove_rent[i] = rightmove_rent[i].str.replace(',','')
    rightmove_rent = rightmove_rent.dropna(subset = [i],axis = 0)
    rightmove_rent[i] = rightmove_rent[i].astype(int)
rightmove_rent.rename(columns = {'Price':'Price_pcm'},inplace = True)
rightmove_rent['No_of_bedroom'] =  rightmove_rent['No_of_bedroom'].str.extract('(\d{1,})').astype('int')
rightmove_rent['No_of_bathroom'] =  rightmove_rent['No_of_bathroom'].str.extract('(\d{1,})').astype('int')

# %%
cols = ['Price','Price_pw']

# %%
rightmove_rent.dtypes
# Out:
# Address           object
# Type              object
# Price_pcm          int32
# Price_pw           int32
# No_of_bedroom      int32
# No_of_bathroom     int32
# description       object
# Agent_name        object
# Agent_website     object
# Agent_contact     object
# Listing_url       object
# dtype: object

# %%
rightmove_rent.head()
# Out:
#                                     Address            Type  Price_pcm  \
# 0  Blythwood Road, Stroud Green, London, N4  End of Terrace       5250
# 1           Kingfisher Heights, London, E16            Flat       1850
# 2              Torriano Avenue, London, NW5            Flat       4500
# 3               Ringstead Road, London, SE6            Flat       1460
# 4                    A Millway, London, NW7      Maisonette       1800
#
#    Price_pw  No_of_bedroom  No_of_bathroom  \
# 0      1212              5               2
# 1       427              1               1
# 2      1038              1               1
# 3       337              1               1
# 4       415              2               1
#
#                                          description  \
# 0  NO DEPOSIT OPTION AVAILABLE. Lovely five bedro...
# 1  Property Description: This beautiful one bedro...
# 2  A wonderfully stylish 1 bedroom apartment loca...
# 3  We are proud to offer this delightful 1 bedroo...
# 4  We are proud to offer this delightful 2 bedroo...
#
#                    Agent_name  \
# 0  Martyn Gerrard, Crouch End
# 1            OpenRent, London
# 2            OpenRent, London
# 3            OpenRent, London
# 4            OpenRent, London
#
#                                        Agent_website  \
# 0  https://www.rightmove.co.uk/estate-agents/agen...
# 1  https://www.rightmove.co.uk/estate-agents/agen...
# 2  https://www.rightmove.co.uk/estate-agents/agen...
# 3  https://www.rightmove.co.uk/estate-agents/agen...
# 4  https://www.rightmove.co.uk/estate-agents/agen...
#
#                                        Agent_contact  \
# 0  https://www.rightmove.co.uk/property-to-rent/c...
# 1  https://www.rightmove.co.uk/property-to-rent/c...
# 2  https://www.rightmove.co.uk/property-to-rent/c...
# 3  https://www.rightmove.co.uk/property-to-rent/c...
# 4  https://www.rightmove.co.uk/property-to-rent/c...
#
#                                          Listing_url
# 0  https://www.rightmove.co.uk/properties/1352645...
# 1  https://www.rightmove.co.uk/properties/1354085...
# 2  https://www.rightmove.co.uk/properties/1354085...
# 3  https://www.rightmove.co.uk/properties/1354085...
# 4  https://www.rightmove.co.uk/properties/1354085...

# %%
#Checking for duplicates
rightmove_rent.duplicated().sum()
# Out:
# 0

# %%
#resetting index
rightmove_rent.reset_index(drop = True,inplace = True)

# %%
# Extracting out the district Postcode present in the Address by using the list of District Postcode in London.
for i, j in enumerate(rightmove_rent['Address']):
    for k in post_list:
        if k in rightmove_rent['Address'][i]:
            rightmove_rent.loc[i, 'Postcode_district'] = k
            break
        else:
            rightmove_rent.loc[i, 'Postcode_district'] = np.NaN

# Filling null values with "None"
rightmove_rent['Postcode_district'].fillna('None', inplace=True)

# Making a copy of the District code yet to be gotten.
rightmove_rent_copy = rightmove_rent.query('Postcode_district == "None"')

# Dropping the index where we have district code to be null
rightmove_rent.drop(rightmove_rent_copy.index, inplace=True)

# Resetting index of the copied data
rightmove_rent_copy.reset_index(drop=True, inplace=True)

# %%
# Using geolocator to get other District codes
geolocator = Nominatim(user_agent="postcode_extractor")
for i, j in enumerate(rightmove_rent_copy['Address']):
    location = geolocator.geocode(rightmove_rent_copy['Address'][i], country_codes="GB", addressdetails=True,timeout = 10)
    if location is not None:
        postcode = location.raw.get('address', {}).get('postcode')
        if postcode:
            rightmove_rent_copy.loc[i, 'Postcode_district'] = postcode.split()[0]
        else:
            rightmove_rent_copy.loc[i, 'Postcode_district'] = 'None'
    else:
        rightmove_rent_copy.loc[i, 'Postcode_district'] = 'None'

# Checking district codes which are yet to be gotten
rightmove_rent_copy = rightmove_rent_copy.query('Postcode_district != "None"')

# Getting the final data
rightmove_rent = pd.concat([rightmove_rent, rightmove_rent_copy], ignore_index=True)

rightmove_rent
# Out:
#                                       Address            Type  Price_pcm  \
# 0    Blythwood Road, Stroud Green, London, N4  End of Terrace       5250
# 1             Kingfisher Heights, London, E16            Flat       1850
# 2                Torriano Avenue, London, NW5            Flat       4500
# 3                 Ringstead Road, London, SE6            Flat       1460
# 4                      A Millway, London, NW7      Maisonette       1800
# ..                                        ...             ...        ...
# 835            94 White Horse Road, Limehouse       Apartment       2561
# 836                            Hightail Point       Apartment       2695
# 837                      Albyn Road, Deptford        Terraced       3250
# 838             Hazelwood Lane, Palmers Green      Maisonette       2197
# 839                Nottingham Terrace, London            Flat       2427
#
#      Price_pw  No_of_bedroom  No_of_bathroom  \
# 0        1212              5               2
# 1         427              1               1
# 2        1038              1               1
# 3         337              1               1
# 4         415              2               1
# ..        ...            ...             ...
# 835       591              2               2
# 836       622              2               2
# 837       750              4               1
# 838       507              3               1
# 839       560              1               1
#
#                                            description  \
# 0    NO DEPOSIT OPTION AVAILABLE. Lovely five bedro...
# 1    Property Description: This beautiful one bedro...
# 2    A wonderfully stylish 1 bedroom apartment loca...
# 3    We are proud to offer this delightful 1 bedroo...
# 4    We are proud to offer this delightful 2 bedroo...
# ..                                                 ...
# 835  ea2 are pleased to offer to let this 2 bedroom...
# 836  In East Village’s newest, most striking develo...
# 837  A four double bedroom Victorian house includin...
# 838  Available from the 26th July on an unfurnished...
# 839  A bright one double bedroom, fourth floor apar...
#
#                                  Agent_name  \
# 0                Martyn Gerrard, Crouch End
# 1                          OpenRent, London
# 2                          OpenRent, London
# 3                          OpenRent, London
# 4                          OpenRent, London
# ..                                      ...
# 835              ea2 Estate Agency, Wapping
# 836  Get Living, East Village by Get Living
# 837                      Dexters, New Cross
# 838              Outlet Residential, London
# 839      Sandfords, Regents Park - Lettings
#
#                                          Agent_website  \
# 0    https://www.rightmove.co.uk/estate-agents/agen...
# 1    https://www.rightmove.co.uk/estate-agents/agen...
# 2    https://www.rightmove.co.uk/estate-agents/agen...
# 3    https://www.rightmove.co.uk/estate-agents/agen...
# 4    https://www.rightmove.co.uk/estate-agents/agen...
# ..                                                 ...
# 835  https://www.rightmove.co.uk/estate-agents/agen...
# 836  https://www.rightmove.co.uk/estate-agents/agen...
# 837  https://www.rightmove.co.uk/estate-agents/agen...
# 838  https://www.rightmove.co.uk/estate-agents/agen...
# 839  https://www.rightmove.co.uk/estate-agents/agen...
#
#                                          Agent_contact  \
# 0    https://www.rightmove.co.uk/property-to-rent/c...
# 1    https://www.rightmove.co.uk/property-to-rent/c...
# 2    https://www.rightmove.co.uk/property-to-rent/c...
# 3    https://www.rightmove.co.uk/property-to-rent/c...
# 4    https://www.rightmove.co.uk/property-to-rent/c...
# ..                                                 ...
# 835  https://www.rightmove.co.uk/property-to-rent/c...
# 836  https://www.rightmove.co.uk/property-to-rent/c...
# 837  https://www.rightmove.co.uk/property-to-rent/c...
# 838  https://www.rightmove.co.uk/property-to-rent/c...
# 839  https://www.rightmove.co.uk/property-to-rent/c...
#
#                                            Listing_url Postcode_district
# 0    https://www.rightmove.co.uk/properties/1352645...                N4
# 1    https://www.rightmove.co.uk/properties/1354085...                E1
# 2    https://www.rightmove.co.uk/properties/1354085...               NW5
# 3    https://www.rightmove.co.uk/properties/1354085...                E6
# 4    https://www.rightmove.co.uk/properties/1354085...               NW7
# ..                                                 ...               ...
# 835  https://www.rightmove.co.uk/properties/1353425...                E1
# 836  https://www.rightmove.co.uk/properties/1353425...               E20
# 837  https://www.rightmove.co.uk/properties/1353423...               SE8
# 838  https://www.rightmove.co.uk/properties/1353422...               N13
# 839  https://www.rightmove.co.uk/properties/1353420...               NW1
#
# [840 rows x 12 columns]

# %%
# Checking district codes which are yet to be gotten
rightmove_rent_copy = rightmove_rent_copy.query('Postcode_district != "None"')

# Getting the final data
rightmove_rent = pd.concat([rightmove_rent, rightmove_rent_copy], ignore_index=True)

rightmove_rent
# Out:
#                                       Address            Type  Price_pcm  \
# 0    Blythwood Road, Stroud Green, London, N4  End of Terrace       5250
# 1             Kingfisher Heights, London, E16            Flat       1850
# 2                Torriano Avenue, London, NW5            Flat       4500
# 3                 Ringstead Road, London, SE6            Flat       1460
# 4                      A Millway, London, NW7      Maisonette       1800
# ..                                        ...             ...        ...
# 945            94 White Horse Road, Limehouse       Apartment       2561
# 946                            Hightail Point       Apartment       2695
# 947                      Albyn Road, Deptford        Terraced       3250
# 948             Hazelwood Lane, Palmers Green      Maisonette       2197
# 949                Nottingham Terrace, London            Flat       2427
#
#      Price_pw  No_of_bedroom  No_of_bathroom  \
# 0        1212              5               2
# 1         427              1               1
# 2        1038              1               1
# 3         337              1               1
# 4         415              2               1
# ..        ...            ...             ...
# 945       591              2               2
# 946       622              2               2
# 947       750              4               1
# 948       507              3               1
# 949       560              1               1
#
#                                            description  \
# 0    NO DEPOSIT OPTION AVAILABLE. Lovely five bedro...
# 1    Property Description: This beautiful one bedro...
# 2    A wonderfully stylish 1 bedroom apartment loca...
# 3    We are proud to offer this delightful 1 bedroo...
# 4    We are proud to offer this delightful 2 bedroo...
# ..                                                 ...
# 945  ea2 are pleased to offer to let this 2 bedroom...
# 946  In East Village’s newest, most striking develo...
# 947  A four double bedroom Victorian house includin...
# 948  Available from the 26th July on an unfurnished...
# 949  A bright one double bedroom, fourth floor apar...
#
#                                  Agent_name  \
# 0                Martyn Gerrard, Crouch End
# 1                          OpenRent, London
# 2                          OpenRent, London
# 3                          OpenRent, London
# 4                          OpenRent, London
# ..                                      ...
# 945              ea2 Estate Agency, Wapping
# 946  Get Living, East Village by Get Living
# 947                      Dexters, New Cross
# 948              Outlet Residential, London
# 949      Sandfords, Regents Park - Lettings
#
#                                          Agent_website  \
# 0    https://www.rightmove.co.uk/estate-agents/agen...
# 1    https://www.rightmove.co.uk/estate-agents/agen...
# 2    https://www.rightmove.co.uk/estate-agents/agen...
# 3    https://www.rightmove.co.uk/estate-agents/agen...
# 4    https://www.rightmove.co.uk/estate-agents/agen...
# ..                                                 ...
# 945  https://www.rightmove.co.uk/estate-agents/agen...
# 946  https://www.rightmove.co.uk/estate-agents/agen...
# 947  https://www.rightmove.co.uk/estate-agents/agen...
# 948  https://www.rightmove.co.uk/estate-agents/agen...
# 949  https://www.rightmove.co.uk/estate-agents/agen...
#
#                                          Agent_contact  \
# 0    https://www.rightmove.co.uk/property-to-rent/c...
# 1    https://www.rightmove.co.uk/property-to-rent/c...
# 2    https://www.rightmove.co.uk/property-to-rent/c...
# 3    https://www.rightmove.co.uk/property-to-rent/c...
# 4    https://www.rightmove.co.uk/property-to-rent/c...
# ..                                                 ...
# 945  https://www.rightmove.co.uk/property-to-rent/c...
# 946  https://www.rightmove.co.uk/property-to-rent/c...
# 947  https://www.rightmove.co.uk/property-to-rent/c...
# 948  https://www.rightmove.co.uk/property-to-rent/c...
# 949  https://www.rightmove.co.uk/property-to-rent/c...
#
#                                            Listing_url Postcode_district
# 0    https://www.rightmove.co.uk/properties/1352645...                N4
# 1    https://www.rightmove.co.uk/properties/1354085...                E1
# 2    https://www.rightmove.co.uk/properties/1354085...               NW5
# 3    https://www.rightmove.co.uk/properties/1354085...                E6
# 4    https://www.rightmove.co.uk/properties/1354085...               NW7
# ..                                                 ...               ...
# 945  https://www.rightmove.co.uk/properties/1353425...                E1
# 946  https://www.rightmove.co.uk/properties/1353425...               E20
# 947  https://www.rightmove.co.uk/properties/1353423...               SE8
# 948  https://www.rightmove.co.uk/properties/1353422...               N13
# 949  https://www.rightmove.co.uk/properties/1353420...               NW1
#
# [950 rows x 12 columns]

# %%
rightmove_rent.rename(columns = {'Type':'Property_type'},inplace = True)
rightmove_rent['Transaction_type'] = np.repeat('rent',rightmove_rent.shape[0])

# %%
rightmove_rent.rename(columns = {'No_of_bedroom':'No_of_Bedroom','No_of_bathroom':'No_of_Bathroom',
                                'description':'Description'},inplace = True)

# %%
rightmove_rent.to_csv('rightmove_rent_master.csv',index = False)

# %% [markdown]
# <p id='wzoopla'></p>
#
# ### ZOOPLA

# %%
#zoopla data
zoopla_sale = pd.read_csv('zoopla_sale.csv')
zoopla_rent = pd.read_csv('zoopla_rent.csv')

# %%
zoopla_sale.drop(columns = ['Unnamed: 0'],inplace = True)

# %%
zoopla_sale.head()
# Out:
#                                              Address                Price  \
# 0                       Arterberry Road, London SW20  Guide price£450,000
# 1                       Arterberry Road, London SW20  Guide price£450,000
# 2  "Block C1 CD13 So - Plot 260" at Oliver Road, ...         From£665,000
# 3              Colegrave Road, Stratford, London E15             £295,000
# 4              Colegrave Road, Stratford, London E15             £295,000
#
#            Description                         Agent_name  \
# 0  1 bed flat for sale              Lucie White & Company
# 1  1 bed flat for sale              Lucie White & Company
# 2  3 bed flat for sale  Taylor Wimpey - Coronation Square
# 3  1 bed flat for sale          Portico Property - Leyton
# 4  1 bed flat for sale          Portico Property - Leyton
#
#                                        Agent_website  \
# 0  https://www.zoopla.co.uk/find-agents/branch/lu...
# 1  https://www.zoopla.co.uk/find-agents/branch/lu...
# 2  https://www.zoopla.co.uk/new-homes/developers/...
# 3  https://www.zoopla.co.uk/find-agents/branch/po...
# 4  https://www.zoopla.co.uk/find-agents/branch/po...
#
#                                        Agent_contact  \
# 0  https://www.zoopla.co.uk/for-sale/details/cont...
# 1  https://www.zoopla.co.uk/for-sale/details/cont...
# 2  https://www.zoopla.co.uk/new-homes/details/con...
# 3  https://www.zoopla.co.uk/for-sale/details/cont...
# 4  https://www.zoopla.co.uk/for-sale/details/cont...
#
#                                          Listing_url  No_of_Bedroom  \
# 0  https://www.zoopla.co.uk/for-sale/details/6467...            1.0
# 1  https://www.zoopla.co.uk/for-sale/details/6467...            NaN
# 2  https://www.zoopla.co.uk/new-homes/details/647...            3.0
# 3  https://www.zoopla.co.uk/for-sale/details/6473...            1.0
# 4  https://www.zoopla.co.uk/for-sale/details/6473...            NaN
#
#    No_of_Bathroom  No_of_livingroom
# 0             1.0               1.0
# 1             NaN               NaN
# 2             NaN               NaN
# 3             1.0               1.0
# 4             NaN               NaN

# %%
zoopla_sale.dtypes
# Out:
# Address              object
# Price                object
# Description          object
# Agent_name           object
# Agent_website        object
# Agent_contact        object
# Listing_url          object
# No_of_Bedroom       float64
# No_of_Bathroom      float64
# No_of_livingroom    float64
# dtype: object

# %%
zoopla_sale = zoopla_sale.dropna(subset = ['Price','No_of_Bedroom','No_of_Bathroom'],axis = 0)
zoopla_sale['Price'] = zoopla_sale['Price'].str.extract('([\d{1,}]+)')
zoopla_sale['Price'] = zoopla_sale['Price'].str.replace(',','')
zoopla_sale['Price'] = zoopla_sale['Price'].astype('int')
zoopla_sale['No_of_Bedroom'] = zoopla_sale['No_of_Bedroom'].astype('int')
zoopla_sale['No_of_Bathroom'] = zoopla_sale['No_of_Bathroom'].astype('int')

# %%
zoopla_sale.dtypes
# Out:
# Address              object
# Price                 int32
# Description          object
# Agent_name           object
# Agent_website        object
# Agent_contact        object
# Listing_url          object
# No_of_Bedroom         int32
# No_of_Bathroom        int32
# No_of_livingroom    float64
# dtype: object

# %%
zoopla_sale['Property_type'] = zoopla_sale.Description.str.extract('([a-zA-Z]+\s+[a-zA-Z.\-]+)',expand = True)

# %%
zoopla_sale['Property_type'] = zoopla_sale['Property_type'].str.replace('bed','')

# %%
zoopla_sale['Transaction_type'] = np.repeat('sale',zoopla_sale.shape[0])

# %%
#checking for duplicates
zoopla_sale.duplicated().sum()
# Out:
# 22

# %%
#Resetting index
zoopla_sale.reset_index(drop = True,inplace = True)
zoopla_sale.head()
# Out:
#                                   Address   Price  \
# 0            Arterberry Road, London SW20  450000
# 1   Colegrave Road, Stratford, London E15  295000
# 2  Chilham Close, Perivale, Greenford UB6  799950
# 3            Frensham Close, Southall UB1  289950
# 4              Berens Road, Orpington BR5  400000
#
#                           Description                 Agent_name  \
# 0                 1 bed flat for sale      Lucie White & Company
# 1                 1 bed flat for sale  Portico Property - Leyton
# 2  4 bed semi-detached house for sale          Peter Gamble & Co
# 3                 2 bed flat for sale           Match A Property
# 4  3 bed semi-detached house for sale      Proctors - Petts Wood
#
#                                        Agent_website  \
# 0  https://www.zoopla.co.uk/find-agents/branch/lu...
# 1  https://www.zoopla.co.uk/find-agents/branch/po...
# 2  https://www.zoopla.co.uk/find-agents/branch/pe...
# 3  https://www.zoopla.co.uk/find-agents/branch/ma...
# 4  https://www.zoopla.co.uk/find-agents/branch/pr...
#
#                                        Agent_contact  \
# 0  https://www.zoopla.co.uk/for-sale/details/cont...
# 1  https://www.zoopla.co.uk/for-sale/details/cont...
# 2  https://www.zoopla.co.uk/for-sale/details/cont...
# 3  https://www.zoopla.co.uk/for-sale/details/cont...
# 4  https://www.zoopla.co.uk/for-sale/details/cont...
#
#                                          Listing_url  No_of_Bedroom  \
# 0  https://www.zoopla.co.uk/for-sale/details/6467...              1
# 1  https://www.zoopla.co.uk/for-sale/details/6473...              1
# 2  https://www.zoopla.co.uk/for-sale/details/6473...              4
# 3  https://www.zoopla.co.uk/for-sale/details/6473...              2
# 4  https://www.zoopla.co.uk/for-sale/details/6473...              3
#
#    No_of_Bathroom  No_of_livingroom   Property_type Transaction_type
# 0               1               1.0            flat             sale
# 1               1               1.0            flat             sale
# 2               2               2.0   semi-detached             sale
# 3               1               1.0            flat             sale
# 4               1               1.0   semi-detached             sale

# %%
# Extracting out the district Postcode present in the Address by using the list of District Postcode in London.
for i, j in enumerate(zoopla_sale['Address']):
    for k in post_list:
        if k in zoopla_sale['Address'][i]:
            zoopla_sale.loc[i, 'Postcode_district'] = k
            break
        else:
            zoopla_sale.loc[i, 'Postcode_district'] = np.NaN

# Filling null values with "None"
zoopla_sale['Postcode_district'].fillna('None', inplace=True)

# Making a copy of the District code yet to be gotten.
zoopla_sale_copy = zoopla_sale.query('Postcode_district == "None"')

# Dropping the index where we have district code to be null
zoopla_sale.drop(zoopla_sale_copy.index, inplace=True)

# Resetting index of the copied data
zoopla_sale_copy.reset_index(drop=True, inplace=True)

# Using geolocator to get other District codes
geolocator = Nominatim(user_agent="postcode_extractor")
for i, j in enumerate(zoopla_sale_copy['Address']):
    location = geolocator.geocode(zoopla_sale_copy['Address'][i], country_codes="GB", addressdetails=True,timeout=10)
    if location is not None:
        postcode = location.raw.get('address', {}).get('postcode')
        if postcode:
            zoopla_sale_copy.loc[i, 'Postcode_district'] = postcode.split()[0]
        else:
            zoopla_sale_copy.loc[i, 'Postcode_district'] = 'None'
    else:
        zoopla_sale_copy.loc[i, 'Postcode_district'] = 'None'

# Checking district codes which are yet to be gotten
zoopla_sale_copy = zoopla_sale_copy.query('Postcode_district != "None"')

# Getting the final data
zoopla_sale = pd.concat([zoopla_sale, zoopla_sale_copy], ignore_index=True)

zoopla_sale
# Out:
#                                     Address    Price  \
# 0              Arterberry Road, London SW20   450000
# 1     Colegrave Road, Stratford, London E15   295000
# 2    Chilham Close, Perivale, Greenford UB6   799950
# 3              Frensham Close, Southall UB1   289950
# 4                Berens Road, Orpington BR5   400000
# ..                                      ...      ...
# 617                  Wood Close, London NW9   650000
# 618               Thames Avenue, London UB6  1000000
# 619                Verwood Road, Harrow HA2   675000
# 620             Brigadier Hill, Enfield EN2   600000
# 621               Cromwell Road, London E17   925000
#
#                             Description  \
# 0                   1 bed flat for sale
# 1                   1 bed flat for sale
# 2    4 bed semi-detached house for sale
# 3                   2 bed flat for sale
# 4    3 bed semi-detached house for sale
# ..                                  ...
# 617       4 bed terraced house for sale
# 618       4 bed terraced house for sale
# 619  4 bed semi-detached house for sale
# 620       4 bed terraced house for sale
# 621       5 bed terraced house for sale
#
#                                       Agent_name  \
# 0                          Lucie White & Company
# 1                      Portico Property - Leyton
# 2                              Peter Gamble & Co
# 3                               Match A Property
# 4                          Proctors - Petts Wood
# ..                                           ...
# 617              Blue Ocean Property Consultants
# 618  Fine & Country - Harrow, Northwood & Pinner
# 619               Major Estates Sales & Lettings
# 620                                  Ideal Place
# 621                      The Stow Brothers - E17
#
#                                          Agent_website  \
# 0    https://www.zoopla.co.uk/find-agents/branch/lu...
# 1    https://www.zoopla.co.uk/find-agents/branch/po...
# 2    https://www.zoopla.co.uk/find-agents/branch/pe...
# 3    https://www.zoopla.co.uk/find-agents/branch/ma...
# 4    https://www.zoopla.co.uk/find-agents/branch/pr...
# ..                                                 ...
# 617  https://www.zoopla.co.uk/find-agents/branch/bl...
# 618  https://www.zoopla.co.uk/find-agents/branch/fi...
# 619  https://www.zoopla.co.uk/find-agents/branch/ma...
# 620  https://www.zoopla.co.uk/find-agents/branch/id...
# 621  https://www.zoopla.co.uk/find-agents/branch/th...
#
#                                          Agent_contact  \
# 0    https://www.zoopla.co.uk/for-sale/details/cont...
# 1    https://www.zoopla.co.uk/for-sale/details/cont...
# 2    https://www.zoopla.co.uk/for-sale/details/cont...
# 3    https://www.zoopla.co.uk/for-sale/details/cont...
# 4    https://www.zoopla.co.uk/for-sale/details/cont...
# ..                                                 ...
# 617  https://www.zoopla.co.uk/for-sale/details/cont...
# 618  https://www.zoopla.co.uk/for-sale/details/cont...
# 619  https://www.zoopla.co.uk/for-sale/details/cont...
# 620  https://www.zoopla.co.uk/for-sale/details/cont...
# 621  https://www.zoopla.co.uk/for-sale/details/cont...
#
#                                            Listing_url  No_of_Bedroom  \
# 0    https://www.zoopla.co.uk/for-sale/details/6467...              1
# 1    https://www.zoopla.co.uk/for-sale/details/6473...              1
# 2    https://www.zoopla.co.uk/for-sale/details/6473...              4
# 3    https://www.zoopla.co.uk/for-sale/details/6473...              2
# 4    https://www.zoopla.co.uk/for-sale/details/6473...              3
# ..                                                 ...            ...
# 617  https://www.zoopla.co.uk/for-sale/details/6472...              4
# 618  https://www.zoopla.co.uk/for-sale/details/6472...              4
# 619  https://www.zoopla.co.uk/for-sale/details/6472...              4
# 620  https://www.zoopla.co.uk/for-sale/details/6472...              4
# 621  https://www.zoopla.co.uk/for-sale/details/6472...              5
#
#      No_of_Bathroom  No_of_livingroom   Property_type Transaction_type  \
# 0                 1               1.0            flat             sale
# 1                 1               1.0            flat             sale
# 2                 2               2.0   semi-detached             sale
# 3                 1               1.0            flat             sale
# 4                 1               1.0   semi-detached             sale
# ..              ...               ...             ...              ...
# 617               2               1.0        terraced             sale
# 618               3               2.0        terraced             sale
# 619               1               1.0   semi-detached             sale
# 620               2               2.0        terraced             sale
# 621               2               1.0        terraced             sale
#
#     Postcode_district
# 0                 SW2
# 1                  E1
# 2                 UB6
# 3                 UB1
# 4                 BR5
# ..                ...
# 617               NW9
# 618               UB6
# 619               HA2
# 620               EN2
# 621                E1
#
# [622 rows x 13 columns]

# %%
zoopla_sale.to_csv('zoopla_sale_master.csv',index = False)

# %%
zoopla_rent.drop(columns = ['Unnamed: 0'],inplace = True)

# %%
zoopla_rent.shape
# Out:
# (1323, 10)

# %%
zoopla_rent = zoopla_rent.dropna(subset = ['Price','No_of_Bedroom','No_of_Bathroom'],axis = 0)
zoopla_rent['Price_pcm'] = zoopla_rent['Price'].str.extract('([\d{1,}]+)')
zoopla_rent['Price_pw'] = zoopla_rent['Price'].str.extract('pcm£([\d{1,}]+)')
zoopla_rent['Price_pcm'] = zoopla_rent['Price_pcm'].str.replace(',','')
zoopla_rent['Price_pw'] = zoopla_rent['Price_pw'].str.replace(',','')
zoopla_rent['Price_pw'] = zoopla_rent['Price_pw'].astype('int')
zoopla_rent['Price_pcm'] = zoopla_rent['Price_pcm'].astype('int')
zoopla_rent['No_of_Bedroom'] = zoopla_rent['No_of_Bedroom'].astype('int')
zoopla_rent['No_of_Bathroom'] = zoopla_rent['No_of_Bathroom'].astype('int')

# %%
zoopla_rent.dtypes
# Out:
# Address              object
# Price                object
# Description          object
# Agent_name           object
# Agent_website        object
# Agent_contact        object
# Listing_url          object
# No_of_Bedroom         int32
# No_of_Bathroom        int32
# No_of_livingroom    float64
# Price_pcm             int32
# Price_pw              int32
# dtype: object

# %%
zoopla_rent.drop(columns = ['Price'],inplace = True)

# %%
zoopla_rent
# Out:
#                                   Address                   Description  \
# 0                  Marsh Wall, London E14            1 bed flat to rent
# 3            Colville Gardens, London W11                Studio to rent
# 5                  Avis Square, London E1  4 bed terraced house to rent
# 6                  Hendon Way, Hendon NW4      2 bed maisonette to rent
# 8     Ealing Road, Wembley, Middlesex HA0            2 bed flat to rent
# ...                                   ...                           ...
# 1316         St. Pauls Avenue, London NW2            1 bed flat to rent
# 1317      Rotherhithe Street, London SE16            1 bed flat to rent
# 1318      Golders Green Road, London NW11            1 bed flat to rent
# 1319         St. Hildas Mount, London NW7            3 bed flat to rent
# 1320         Embassy Gardens, London SW11            2 bed flat to rent
#
#                        Agent_name  \
# 0                 AD and Partners
# 3          Homelike Internet GmbH
# 5                      Right Room
# 6            Brampton Real Estate
# 8        Right Home Estate Agents
# ...                           ...
# 1316                     OpenRent
# 1317                     OpenRent
# 1318                     OpenRent
# 1319                     OpenRent
# 1320  One Move Property Group Ltd
#
#                                           Agent_website  \
# 0     https://www.zoopla.co.uk/find-agents/branch/ad...
# 3     https://www.zoopla.co.uk/find-agents/branch/ho...
# 5     https://www.zoopla.co.uk/find-agents/branch/ri...
# 6     https://www.zoopla.co.uk/find-agents/branch/br...
# 8     https://www.zoopla.co.uk/find-agents/branch/ri...
# ...                                                 ...
# 1316  https://www.zoopla.co.uk/find-agents/branch/op...
# 1317  https://www.zoopla.co.uk/find-agents/branch/op...
# 1318  https://www.zoopla.co.uk/find-agents/branch/op...
# 1319  https://www.zoopla.co.uk/find-agents/branch/op...
# 1320  https://www.zoopla.co.uk/find-agents/branch/on...
#
#                                           Agent_contact  \
# 0     https://www.zoopla.co.uk/to-rent/details/conta...
# 3     https://www.zoopla.co.uk/to-rent/details/conta...
# 5     https://www.zoopla.co.uk/to-rent/details/conta...
# 6     https://www.zoopla.co.uk/to-rent/details/conta...
# 8     https://www.zoopla.co.uk/to-rent/details/conta...
# ...                                                 ...
# 1316  https://www.zoopla.co.uk/to-rent/details/conta...
# 1317  https://www.zoopla.co.uk/to-rent/details/conta...
# 1318  https://www.zoopla.co.uk/to-rent/details/conta...
# 1319  https://www.zoopla.co.uk/to-rent/details/conta...
# 1320  https://www.zoopla.co.uk/to-rent/details/conta...
#
#                                             Listing_url  No_of_Bedroom  \
# 0     https://www.zoopla.co.uk/to-rent/details/64733...              1
# 3     https://www.zoopla.co.uk/to-rent/details/57653...              1
# 5     https://www.zoopla.co.uk/to-rent/details/64732...              4
# 6     https://www.zoopla.co.uk/to-rent/details/64732...              2
# 8     https://www.zoopla.co.uk/to-rent/details/64732...              2
# ...                                                 ...            ...
# 1316  https://www.zoopla.co.uk/to-rent/details/64725...              1
# 1317  https://www.zoopla.co.uk/to-rent/details/64725...              1
# 1318  https://www.zoopla.co.uk/to-rent/details/64725...              1
# 1319  https://www.zoopla.co.uk/to-rent/details/64725...              3
# 1320  https://www.zoopla.co.uk/to-rent/details/62487...              2
#
#       No_of_Bathroom  No_of_livingroom  Price_pcm  Price_pw
# 0                  1               1.0       3683       850
# 3                  1               NaN       2300       531
# 5                  1               1.0       3600       831
# 6                  2               1.0       1950       450
# 8                  1               NaN       2100       485
# ...              ...               ...        ...       ...
# 1316               1               NaN       1650       381
# 1317               1               NaN        999       231
# 1318               2               NaN        825       190
# 1319               2               NaN       2600       600
# 1320               2               1.0       3900       900
#
# [805 rows x 11 columns]

# %%
zoopla_rent['Property_type'] = zoopla_rent['Description'].str.extract('([a-zA-Z]+\s+[a-zA-Z.\-]+)',expand = True)

# %%
zoopla_rent['Property_type'] = zoopla_rent['Property_type'].str.replace('bed','')

# %%
zoopla_rent['Property_type'] = zoopla_rent['Property_type'].str.strip()

# %%
zoopla_rent['Property_type'] = zoopla_rent['Property_type'].apply(lambda x:x.split(' ')[0])

# %%
zoopla_rent['Transaction_type'] = np.repeat('rent',zoopla_rent.shape[0])

# %%
#checking for Duplicates
zoopla_rent.duplicated().sum()
# Out:
# 22

# %%
#Resetting index
zoopla_rent.reset_index(drop = True,inplace = True)

# %%
# Extracting out the district Postcode present in the Address by using the list of District Postcode in London.
for i, j in enumerate(zoopla_rent['Address']):
    for k in post_list:
        if k in zoopla_rent['Address'][i]:
            zoopla_rent.loc[i, 'Postcode_district'] = k
            break
        else:
            zoopla_rent.loc[i, 'Postcode_district'] = np.NaN

# Filling null values with "None"
zoopla_rent['Postcode_district'].fillna('None', inplace=True)

# Making a copy of the District code yet to be gotten.
zoopla_rent_copy = zoopla_rent.query('Postcode_district == "None"')

# Dropping the index where we have district code to be null
zoopla_rent.drop(zoopla_rent_copy.index, inplace=True)

# Resetting index of the copied data
zoopla_rent_copy.reset_index(drop=True, inplace=True)

# Using geolocator to get other District codes
geolocator = Nominatim(user_agent="postcode_extractor")
for i, j in enumerate(zoopla_rent_copy['Address']):
    location = geolocator.geocode(zoopla_rent_copy['Address'][i], country_codes="GB", addressdetails=True,timeout = 10)
    if location is not None:
        postcode = location.raw.get('address', {}).get('postcode')
        if postcode:
            zoopla_rent_copy.loc[i, 'Postcode_district'] = postcode.split()[0]
        else:
            zoopla_rent_copy.loc[i, 'Postcode_district'] = 'None'
    else:
        zoopla_rent_copy.loc[i, 'Postcode_district'] = 'None'

# Checking district codes which are yet to be gotten
zoopla_rent_copy = zoopla_rent_copy.query('Postcode_district != "None"')

# Getting the final data
zoopla_rent = pd.concat([zoopla_rent, zoopla_rent_copy], ignore_index=True)

zoopla_rent
# Out:
#                                  Address                   Description  \
# 0                 Marsh Wall, London E14            1 bed flat to rent
# 1           Colville Gardens, London W11                Studio to rent
# 2                 Avis Square, London E1  4 bed terraced house to rent
# 3                 Hendon Way, Hendon NW4      2 bed maisonette to rent
# 4    Ealing Road, Wembley, Middlesex HA0            2 bed flat to rent
# ..                                   ...                           ...
# 799      Rotherhithe Street, London SE16            1 bed flat to rent
# 800      Golders Green Road, London NW11            1 bed flat to rent
# 801         St. Hildas Mount, London NW7            3 bed flat to rent
# 802         Embassy Gardens, London SW11            2 bed flat to rent
# 803          City Of London, London EC3R            1 bed flat to rent
#
#                       Agent_name  \
# 0                AD and Partners
# 1         Homelike Internet GmbH
# 2                     Right Room
# 3           Brampton Real Estate
# 4       Right Home Estate Agents
# ..                           ...
# 799                     OpenRent
# 800                     OpenRent
# 801                     OpenRent
# 802  One Move Property Group Ltd
# 803                   Blueground
#
#                                          Agent_website  \
# 0    https://www.zoopla.co.uk/find-agents/branch/ad...
# 1    https://www.zoopla.co.uk/find-agents/branch/ho...
# 2    https://www.zoopla.co.uk/find-agents/branch/ri...
# 3    https://www.zoopla.co.uk/find-agents/branch/br...
# 4    https://www.zoopla.co.uk/find-agents/branch/ri...
# ..                                                 ...
# 799  https://www.zoopla.co.uk/find-agents/branch/op...
# 800  https://www.zoopla.co.uk/find-agents/branch/op...
# 801  https://www.zoopla.co.uk/find-agents/branch/op...
# 802  https://www.zoopla.co.uk/find-agents/branch/on...
# 803  https://www.zoopla.co.uk/find-agents/branch/bl...
#
#                                          Agent_contact  \
# 0    https://www.zoopla.co.uk/to-rent/details/conta...
# 1    https://www.zoopla.co.uk/to-rent/details/conta...
# 2    https://www.zoopla.co.uk/to-rent/details/conta...
# 3    https://www.zoopla.co.uk/to-rent/details/conta...
# 4    https://www.zoopla.co.uk/to-rent/details/conta...
# ..                                                 ...
# 799  https://www.zoopla.co.uk/to-rent/details/conta...
# 800  https://www.zoopla.co.uk/to-rent/details/conta...
# 801  https://www.zoopla.co.uk/to-rent/details/conta...
# 802  https://www.zoopla.co.uk/to-rent/details/conta...
# 803  https://www.zoopla.co.uk/to-rent/details/conta...
#
#                                            Listing_url  No_of_Bedroom  \
# 0    https://www.zoopla.co.uk/to-rent/details/64733...              1
# 1    https://www.zoopla.co.uk/to-rent/details/57653...              1
# 2    https://www.zoopla.co.uk/to-rent/details/64732...              4
# 3    https://www.zoopla.co.uk/to-rent/details/64732...              2
# 4    https://www.zoopla.co.uk/to-rent/details/64732...              2
# ..                                                 ...            ...
# 799  https://www.zoopla.co.uk/to-rent/details/64725...              1
# 800  https://www.zoopla.co.uk/to-rent/details/64725...              1
# 801  https://www.zoopla.co.uk/to-rent/details/64725...              3
# 802  https://www.zoopla.co.uk/to-rent/details/62487...              2
# 803  https://www.zoopla.co.uk/to-rent/details/64730...              1
#
#      No_of_Bathroom  No_of_livingroom  Price_pcm  Price_pw Property_type  \
# 0                 1               1.0       3683       850          flat
# 1                 1               NaN       2300       531        Studio
# 2                 1               1.0       3600       831      terraced
# 3                 2               1.0       1950       450    maisonette
# 4                 1               NaN       2100       485          flat
# ..              ...               ...        ...       ...           ...
# 799               1               NaN        999       231          flat
# 800               2               NaN        825       190          flat
# 801               2               NaN       2600       600          flat
# 802               2               1.0       3900       900          flat
# 803               1               NaN       2800       646          flat
#
#     Transaction_type Postcode_district
# 0               rent                E1
# 1               rent               W11
# 2               rent                E1
# 3               rent               NW4
# 4               rent               HA0
# ..               ...               ...
# 799             rent                E1
# 800             rent               NW1
# 801             rent               NW7
# 802             rent              SW11
# 803             rent              EC3R
#
# [804 rows x 14 columns]

# %%
zoopla_rent.to_csv('zoopla_rent_master.csv',index = False)

# %% [markdown]
# <p id='wotm'></p>
#
# ## OTM

# %%
#onthemove data
otm_sale = pd.read_csv('otm_sale.csv')
otm_rent = pd.read_csv('otm_rent.csv')

# %%
otm_sale.drop(columns = ['Unnamed: 0'],inplace = True)

# %%
otm_sale.head()
# Out:
#         Price                                Address  \
# 0  £4,750,000           Frognal Lane, Hampstead, NW3
# 1    £800,000  Stephendale Road, Fulham, London, SW6
# 2    £400,000               Broadfield Road, Catford
# 3  £2,600,000                  Millbank, London SW1P
# 4    £575,000                   The Downs, Wimbledon
#
#                 description No_of_bedroom No_of_bathroom  \
# 0  4 bedroom house for sale             4              2
# 1   2 bedroom flat for sale             2              2
# 2   2 bedroom flat for sale             2              1
# 3   2 bedroom flat for sale             2              2
# 4   2 bedroom flat for sale             2              1
#
#                                      listing_url  \
# 0  https://www.onthemarket.com/details/13184464/
# 1  https://www.onthemarket.com/details/13262722/
# 2  https://www.onthemarket.com/details/13262059/
# 3  https://www.onthemarket.com/details/13261993/
# 4  https://www.onthemarket.com/details/13261935/
#
#                                        agent_website  \
# 0  https://www.onthemarket.com/agents/branch/tk-i...
# 1  https://www.onthemarket.com/agents/branch/aspi...
# 2  https://www.onthemarket.com/agents/branch/kinl...
# 3  https://www.onthemarket.com/agents/branch/trev...
# 4  https://www.onthemarket.com/agents/branch/kinl...
#
#                                      agent_name
# 0                  TK International - Hampstead
# 1                         Aspire - Fulham South
# 2    Kinleigh Folkard & Hayward - Catford Sales
# 3                Trevlyn Properties - Maidstone
# 4  Kinleigh Folkard & Hayward - Wimbledon Sales

# %%
otm_sale.dtypes
# Out:
# Price             object
# Address           object
# description       object
# No_of_bedroom     object
# No_of_bathroom    object
# listing_url       object
# agent_website     object
# agent_name        object
# dtype: object

# %%
otm_sale = otm_sale.dropna(subset = ['Price','No_of_bedroom','No_of_bathroom'],axis = 0)
otm_sale['Price'] = otm_sale['Price'].str.extract('([\d{1,}]+)')
otm_sale['Price'] = otm_sale['Price'].str.replace(',','')
otm_sale['Price'] = otm_sale['Price'].astype('int')
otm_sale['No_of_bedroom'] = otm_sale['No_of_bedroom'].str.extract('([\d{1,2}]+)')
otm_sale['No_of_bathroom'] = otm_sale['No_of_bathroom'].str.extract('([\d{1,}]+)')
otm_sale = otm_sale.dropna(subset = ['Price','No_of_bedroom','No_of_bathroom'],axis = 0)
otm_sale['No_of_bedroom'] = otm_sale['No_of_bedroom'].astype('int')
otm_sale['No_of_bathroom'] = otm_sale['No_of_bathroom'].astype('int')

# %%
otm_sale.reset_index(drop = True,inplace = True)

# %%
otm_sale.head()
# Out:
#      Price                                Address               description  \
# 0  4750000           Frognal Lane, Hampstead, NW3  4 bedroom house for sale
# 1   800000  Stephendale Road, Fulham, London, SW6   2 bedroom flat for sale
# 2   400000               Broadfield Road, Catford   2 bedroom flat for sale
# 3  2600000                  Millbank, London SW1P   2 bedroom flat for sale
# 4   575000                   The Downs, Wimbledon   2 bedroom flat for sale
#
#    No_of_bedroom  No_of_bathroom  \
# 0              4               2
# 1              2               2
# 2              2               1
# 3              2               2
# 4              2               1
#
#                                      listing_url  \
# 0  https://www.onthemarket.com/details/13184464/
# 1  https://www.onthemarket.com/details/13262722/
# 2  https://www.onthemarket.com/details/13262059/
# 3  https://www.onthemarket.com/details/13261993/
# 4  https://www.onthemarket.com/details/13261935/
#
#                                        agent_website  \
# 0  https://www.onthemarket.com/agents/branch/tk-i...
# 1  https://www.onthemarket.com/agents/branch/aspi...
# 2  https://www.onthemarket.com/agents/branch/kinl...
# 3  https://www.onthemarket.com/agents/branch/trev...
# 4  https://www.onthemarket.com/agents/branch/kinl...
#
#                                      agent_name
# 0                  TK International - Hampstead
# 1                         Aspire - Fulham South
# 2    Kinleigh Folkard & Hayward - Catford Sales
# 3                Trevlyn Properties - Maidstone
# 4  Kinleigh Folkard & Hayward - Wimbledon Sales

# %%
otm_sale.rename(columns = {'description':'Description'},inplace = True)

# %%
otm_sale['Property_type'] = otm_sale['Description'].str.extract('([a-zA-Z]+\s+[a-zA-Z.\-]+)',expand = True)

# %%
otm_sale['Property_type'] = otm_sale['Property_type'].str.replace('bedroom','')

# %%
otm_sale['Transaction_type'] = np.repeat('sale',otm_sale.shape[0])

# %%
otm_sale.rename(columns = {'No_of_bedroom':'No_of_Bedroom','No_of_bathroom':'No_of_Bathroom'},inplace = True)

# %%
#checking for Duplicates
otm_sale.duplicated().sum()
# Out:
# 80

# %%
#Dropping Duplicates
otm_sale = otm_sale.drop_duplicates()

# %%
otm_sale.reset_index(drop = True,inplace = True)

# %%
otm_sale.head()
# Out:
#      Price                                Address               Description  \
# 0  4750000           Frognal Lane, Hampstead, NW3  4 bedroom house for sale
# 1   800000  Stephendale Road, Fulham, London, SW6   2 bedroom flat for sale
# 2   400000               Broadfield Road, Catford   2 bedroom flat for sale
# 3  2600000                  Millbank, London SW1P   2 bedroom flat for sale
# 4   575000                   The Downs, Wimbledon   2 bedroom flat for sale
#
#    No_of_Bedroom  No_of_Bathroom  \
# 0              4               2
# 1              2               2
# 2              2               1
# 3              2               2
# 4              2               1
#
#                                      listing_url  \
# 0  https://www.onthemarket.com/details/13184464/
# 1  https://www.onthemarket.com/details/13262722/
# 2  https://www.onthemarket.com/details/13262059/
# 3  https://www.onthemarket.com/details/13261993/
# 4  https://www.onthemarket.com/details/13261935/
#
#                                        agent_website  \
# 0  https://www.onthemarket.com/agents/branch/tk-i...
# 1  https://www.onthemarket.com/agents/branch/aspi...
# 2  https://www.onthemarket.com/agents/branch/kinl...
# 3  https://www.onthemarket.com/agents/branch/trev...
# 4  https://www.onthemarket.com/agents/branch/kinl...
#
#                                      agent_name Property_type Transaction_type
# 0                  TK International - Hampstead         house             sale
# 1                         Aspire - Fulham South          flat             sale
# 2    Kinleigh Folkard & Hayward - Catford Sales          flat             sale
# 3                Trevlyn Properties - Maidstone          flat             sale
# 4  Kinleigh Folkard & Hayward - Wimbledon Sales          flat             sale

# %%
# Extracting out the district Postcode present in the Address by using the list of District Postcode in London.
for i, j in enumerate(otm_sale['Address']):
    for k in post_list:
        if k in otm_sale['Address'][i]:
            otm_sale.loc[i, 'Postcode_district'] = k
            break
        else:
            otm_sale.loc[i, 'Postcode_district'] = np.NaN

# Filling null values with "None"
otm_sale['Postcode_district'].fillna('None', inplace=True)

# Making a copy of the District code yet to be gotten.
otm_sale_copy = otm_sale.query('Postcode_district == "None"')

# Dropping the index where we have district code to be null
otm_sale.drop(otm_sale_copy.index, inplace=True)

# Resetting index of the copied data
otm_sale_copy.reset_index(drop=True, inplace=True)

# Using geolocator to get other District codes
geolocator = Nominatim(user_agent="postcode_extractor")
for i, j in enumerate(otm_sale_copy['Address']):
    location = geolocator.geocode(otm_sale_copy['Address'][i], country_codes="GB", addressdetails=True,timeout = 10)
    if location is not None:
        postcode = location.raw.get('address', {}).get('postcode')
        if postcode:
            otm_sale_copy.loc[i, 'Postcode_district'] = postcode.split()[0]
        else:
            otm_sale_copy.loc[i, 'Postcode_district'] = 'None'
    else:
        otm_sale_copy.loc[i, 'Postcode_district'] = 'None'

# Checking district codes which are yet to be gotten
otm_sale_copy = otm_sale_copy.query('Postcode_district != "None"')

# Getting the final data
otm_sale = pd.concat([otm_sale, otm_sale_copy], ignore_index=True)

otm_sale
# Out:
#        Price                                Address  \
# 0    4750000           Frognal Lane, Hampstead, NW3
# 1     800000  Stephendale Road, Fulham, London, SW6
# 2    2600000                  Millbank, London SW1P
# 3     250000                 Cundy Road, London E16
# 4    7500000         Gloucester Square, London, W2.
# ..       ...                                    ...
# 674   400000                   Mare Street, Hackney
# 675   650000              Ingleby Gardens, Chigwell
# 676   350000              Inglewood Close, Hainault
# 677   350000                  Turner Avenue, London
# 678   445000             Knights Hill, West Norwood
#
#                                 Description  No_of_Bedroom  No_of_Bathroom  \
# 0                  4 bedroom house for sale              4               2
# 1                   2 bedroom flat for sale              2               2
# 2                   2 bedroom flat for sale              2               2
# 3                   1 bedroom flat for sale              1               1
# 4         7 bedroom terraced house for sale              7               4
# ..                                      ...            ...             ...
# 674                 1 bedroom flat for sale              1               1
# 675  3 bedroom semi-detached house for sale              3               1
# 676       3 bedroom terraced house for sale              3               1
# 677           4 bedroom maisonette for sale              4               1
# 678                 3 bedroom flat for sale              3               1
#
#                                        listing_url  \
# 0    https://www.onthemarket.com/details/13184464/
# 1    https://www.onthemarket.com/details/13262722/
# 2    https://www.onthemarket.com/details/13261993/
# 3    https://www.onthemarket.com/details/13261889/
# 4    https://www.onthemarket.com/details/13261878/
# ..                                             ...
# 674  https://www.onthemarket.com/details/13256622/
# 675  https://www.onthemarket.com/details/13152350/
# 676  https://www.onthemarket.com/details/13114711/
# 677  https://www.onthemarket.com/details/13256406/
# 678  https://www.onthemarket.com/details/12273929/
#
#                                          agent_website  \
# 0    https://www.onthemarket.com/agents/branch/tk-i...
# 1    https://www.onthemarket.com/agents/branch/aspi...
# 2    https://www.onthemarket.com/agents/branch/trev...
# 3    https://www.onthemarket.com/agents/branch/trev...
# 4    https://www.onthemarket.com/agents/branch/knig...
# ..                                                 ...
# 674  https://www.onthemarket.com/agents/branch/wild...
# 675  https://www.onthemarket.com/agents/branch/bowd...
# 676  https://www.onthemarket.com/agents/branch/bowd...
# 677  https://www.onthemarket.com/agents/branch/bowd...
# 678  https://www.onthemarket.com/agents/branch/kinl...
#
#                                     agent_name   Property_type  \
# 0                 TK International - Hampstead           house
# 1                        Aspire - Fulham South            flat
# 2               Trevlyn Properties - Maidstone            flat
# 3               Trevlyn Properties - Maidstone            flat
# 4                     Knight Frank - Hyde Park        terraced
# ..                                         ...             ...
# 674                       Wild & Co. - Hackney            flat
# 675                     Bowden Bradley - Essex   semi-detached
# 676                     Bowden Bradley - Essex        terraced
# 677                     Bowden Bradley - Essex      maisonette
# 678  Kinleigh Folkard & Hayward - West Dulwich            flat
#
#     Transaction_type Postcode_district
# 0               sale               NW3
# 1               sale               SW6
# 2               sale              SW1P
# 3               sale                E1
# 4               sale                W2
# ..               ...               ...
# 674             sale                E8
# 675             sale               IG7
# 676             sale               IG6
# 677             sale               N15
# 678             sale              SE27
#
# [679 rows x 11 columns]

# %%
otm_sale.rename(columns = {'listing_url':'Listing_url','agent_website':'Agent_website',
                                'agent_name':'Agent_name'},inplace = True)

# %%
otm_sale.to_csv('otm_sale_master.csv',index = False)

# %%
otm_rent
# Out:
#      Unnamed: 0                    Price  \
# 0             0  £14,083 pcm (£3,250 pw)
# 1             1     £3,467 pcm (£800 pw)
# 2             2     £2,250 pcm (£519 pw)
# 3             3     £2,000 pcm (£462 pw)
# 4             4     £1,350 pcm (£312 pw)
# ..          ...                      ...
# 961         961     £1,995 pcm (£460 pw)
# 962         962     £3,600 pcm (£831 pw)
# 963         963     £1,400 pcm (£323 pw)
# 964         964     £1,800 pcm (£415 pw)
# 965         965     £2,100 pcm (£485 pw)
#
#                                   Address  \
# 0    Stafford Terrace, Kensington, London
# 1     Bathurst Mews, Tyburnia, London, W2
# 2              Mandalay Road, London, SW4
# 3              Wellsmoor Gardens, Bickley
# 4             Saville Row, Hayes, Bromley
# ..                                    ...
# 961                   Nicoll Road, London
# 962                 Ashfield Road, London
# 963                Lancaster Road, Barnet
# 964                   Avenue Road, London
# 965              East Barnet Road, Barnet
#
#                                 description No_of_bedroom No_of_bathroom  \
# 0                    3 bedroom flat to rent             3              2
# 1                    2 bedroom mews to rent             2              2
# 2                    2 bedroom flat to rent             2              1
# 3          3 bedroom terraced house to rent             3              1
# 4    1 bedroom end of terrace house to rent             1              1
# ..                                      ...           ...            ...
# 961                  2 bedroom flat to rent             2              1
# 962                 4 bedroom house to rent             4              1
# 963                  1 bedroom flat to rent             1              1
# 964                  2 bedroom flat to rent             2              1
# 965                  3 bedroom flat to rent             3              1
#
#                                        listing_url  \
# 0    https://www.onthemarket.com/details/11867187/
# 1     https://www.onthemarket.com/details/2601555/
# 2    https://www.onthemarket.com/details/13262721/
# 3     https://www.onthemarket.com/details/9422630/
# 4    https://www.onthemarket.com/details/13262682/
# ..                                             ...
# 961  https://www.onthemarket.com/details/13258607/
# 962  https://www.onthemarket.com/details/13258602/
# 963  https://www.onthemarket.com/details/13258598/
# 964  https://www.onthemarket.com/details/13258597/
# 965  https://www.onthemarket.com/details/13182824/
#
#                                          agent_website  \
# 0    https://www.onthemarket.com/agents/branch/ches...
# 1    https://www.onthemarket.com/agents/branch/luro...
# 2    https://www.onthemarket.com/agents/branch/aspi...
# 3    https://www.onthemarket.com/agents/branch/hump...
# 4    https://www.onthemarket.com/agents/branch/hump...
# ..                                                 ...
# 961  https://www.onthemarket.com/agents/branch/suns...
# 962  https://www.onthemarket.com/agents/branch/suns...
# 963  https://www.onthemarket.com/agents/branch/suns...
# 964  https://www.onthemarket.com/agents/branch/suns...
# 965  https://www.onthemarket.com/agents/branch/suns...
#
#                                agent_name
# 0    Chestertons - Kensington High Street
# 1                 Lurot Brand - Hyde Park
# 2            Aspire - Clapham High Street
# 3          Humphriss & Ryde - Chislehurst
# 4          Humphriss & Ryde - Chislehurst
# ..                                    ...
# 961             Sunshine Estates - London
# 962             Sunshine Estates - London
# 963             Sunshine Estates - London
# 964             Sunshine Estates - London
# 965             Sunshine Estates - London
#
# [966 rows x 9 columns]

# %%
otm_rent.drop(columns = ['Unnamed: 0'],inplace = True)

# %%
otm_rent = otm_rent.dropna(subset = ['Price','No_of_bedroom','No_of_bathroom'],axis = 0)
otm_rent['Price_pcm'] = otm_rent['Price'].str.extract('([\d{1,}]+)')
otm_rent['Price_pw'] = otm_rent['Price'].str.extract('pcm \W+([\d{1,}]+)')
otm_rent['Price_pcm'] = otm_rent['Price_pcm'].str.replace(',','')
otm_rent['Price_pw'] = otm_rent['Price_pw'].str.replace(',','')
otm_rent['Price_pw'] = otm_rent['Price_pw'].astype('int')
otm_rent['Price_pcm'] = otm_rent['Price_pcm'].astype('int')
otm_rent['No_of_bedroom'] = otm_rent['No_of_bedroom'].str.extract('([\d{1,2}]+)')
otm_rent['No_of_bathroom'] = otm_rent['No_of_bathroom'].str.extract('([\d{1,}]+)')
otm_rent = otm_rent.dropna(subset = ['Price','No_of_bedroom','No_of_bathroom'],axis = 0)
otm_rent['No_of_bedroom'] = otm_rent['No_of_bedroom'].astype('int')
otm_rent['No_of_bathroom'] = otm_rent['No_of_bathroom'].astype('int')

# %%
otm_rent.reset_index(drop = True,inplace = True)

# %%
otm_rent.rename(columns = {'No_of_bedroom':'No_of_Bedroom','No_of_bathroom':'No_of_Bathroom'},inplace = True)

# %%
otm_rent.rename(columns = {'description':'Description'},inplace = True)

# %%
otm_rent['Property_type'] = otm_rent['Description'].str.extract('([a-zA-Z]+\s+[a-zA-Z.\-]+)',expand = True)

# %%
otm_rent['Property_type'] = otm_rent['Property_type'].str.replace('bedroom','')

# %%
otm_rent['Transaction_type'] = np.repeat('rent',otm_rent.shape[0])

# %%
otm_rent.drop('Price',axis = 1,inplace = True)

# %%
#checking for duplicates
otm_rent.duplicated().sum()
# Out:
# 198

# %%
#Dropping duplicates
otm_rent = otm_rent.drop_duplicates()

# %%
otm_rent.reset_index(drop = True,inplace = True)

# %%
# Extracting out the district Postcode present in the Address by using the list of District Postcode in London.
for i, j in enumerate(otm_rent['Address']):
    for k in post_list:
        if k in otm_rent['Address'][i]:
            otm_rent.loc[i, 'Postcode_district'] = k
            break
        else:
            otm_rent.loc[i, 'Postcode_district'] = np.NaN

# Filling null values with "None"
otm_rent['Postcode_district'].fillna('None', inplace=True)

# Making a copy of the District code yet to be gotten.
otm_rent_copy = otm_rent.query('Postcode_district == "None"')

# Dropping the index where we have district code to be null
otm_rent.drop(otm_rent_copy.index, inplace=True)

# Resetting index of the copied data
otm_rent_copy.reset_index(drop=True, inplace=True)

# Using geolocator to get other District codes
geolocator = Nominatim(user_agent="postcode_extractor")
for i, j in enumerate(otm_rent_copy['Address']):
    location = geolocator.geocode(otm_rent_copy['Address'][i], country_codes="GB", addressdetails=True,timeout = 10)
    if location is not None:
        postcode = location.raw.get('address', {}).get('postcode')
        if postcode:
            otm_rent_copy.loc[i, 'Postcode_district'] = postcode.split()[0]
        else:
            otm_rent_copy.loc[i, 'Postcode_district'] = 'None'
    else:
        otm_rent_copy.loc[i, 'Postcode_district'] = 'None'

# Checking district codes which are yet to be gotten
otm_rent_copy = otm_rent_copy.query('Postcode_district != "None"')

# Getting the final data
otm_rent = pd.concat([otm_rent, otm_rent_copy], ignore_index=True)

otm_rent
# Out:
#                                  Address                        Description  \
# 0    Bathurst Mews, Tyburnia, London, W2             2 bedroom mews to rent
# 1             Mandalay Road, London, SW4             2 bedroom flat to rent
# 2               Warwick Place, London W5          2 bedroom cottage to rent
# 3          Staplehurst Court, London SE2  1 bedroom in a flat share to rent
# 4           Sherbrooke Road, London, SW6            3 bedroom house to rent
# ..                                   ...                                ...
# 627                  Nicoll Road, London             2 bedroom flat to rent
# 628                Ashfield Road, London            4 bedroom house to rent
# 629               Lancaster Road, Barnet             1 bedroom flat to rent
# 630                  Avenue Road, London             2 bedroom flat to rent
# 631             East Barnet Road, Barnet             3 bedroom flat to rent
#
#      No_of_Bedroom  No_of_Bathroom  \
# 0                2               2
# 1                2               1
# 2                2               1
# 3                1               1
# 4                3               2
# ..             ...             ...
# 627              2               1
# 628              4               1
# 629              1               1
# 630              2               1
# 631              3               1
#
#                                        listing_url  \
# 0     https://www.onthemarket.com/details/2601555/
# 1    https://www.onthemarket.com/details/13262721/
# 2    https://www.onthemarket.com/details/13261879/
# 3    https://www.onthemarket.com/details/13261578/
# 4    https://www.onthemarket.com/details/11825147/
# ..                                             ...
# 627  https://www.onthemarket.com/details/13258607/
# 628  https://www.onthemarket.com/details/13258602/
# 629  https://www.onthemarket.com/details/13258598/
# 630  https://www.onthemarket.com/details/13258597/
# 631  https://www.onthemarket.com/details/13182824/
#
#                                          agent_website  \
# 0    https://www.onthemarket.com/agents/branch/luro...
# 1    https://www.onthemarket.com/agents/branch/aspi...
# 2    https://www.onthemarket.com/agents/branch/tayl...
# 3    https://www.onthemarket.com/agents/branch/home...
# 4    https://www.onthemarket.com/agents/branch/aspi...
# ..                                                 ...
# 627  https://www.onthemarket.com/agents/branch/suns...
# 628  https://www.onthemarket.com/agents/branch/suns...
# 629  https://www.onthemarket.com/agents/branch/suns...
# 630  https://www.onthemarket.com/agents/branch/suns...
# 631  https://www.onthemarket.com/agents/branch/suns...
#
#                          agent_name  Price_pcm  Price_pw Property_type  \
# 0           Lurot Brand - Hyde Park       3467       800          mews
# 1      Aspire - Clapham High Street       2250       519          flat
# 2              Taylor Smith - Acton       2100       485       cottage
# 3    Home World Management - London        750       173            in
# 4             Aspire - Fulham South       3250       750         house
# ..                              ...        ...       ...           ...
# 627       Sunshine Estates - London       1995       460          flat
# 628       Sunshine Estates - London       3600       831         house
# 629       Sunshine Estates - London       1400       323          flat
# 630       Sunshine Estates - London       1800       415          flat
# 631       Sunshine Estates - London       2100       485          flat
#
#     Transaction_type Postcode_district
# 0               rent                W2
# 1               rent               SW4
# 2               rent                W5
# 3               rent                E2
# 4               rent               SW6
# ..               ...               ...
# 627             rent              NW10
# 628             rent                N4
# 629             rent               EN4
# 630             rent               BR3
# 631             rent               EN4
#
# [632 rows x 12 columns]

# %%
otm_rent.rename(columns = {'listing_url':'Listing_url','agent_website':'Agent_website',
                                'agent_name':'Agent_name'},inplace = True)

# %%
otm_rent.to_csv('otm_rent_master.csv',index = False)

# %% [markdown]
# [GoToTop](#top)
#
# <p id='model'></p>
#
# ## DATA MODELLING

# %%
#Creating a master list for all properties available for sale in London
sales = pd.concat([rightmove_sale,zoopla_sale,otm_sale])

# %%
sales
# Out:
#                                          Address   Property_type     Price  \
# 0                          Glyn Road, London, E5        Terraced   1100000
# 1                   Lygon Place, Belgravia, SW1W           House  45000000
# 2    Mayfair Freehold House, Park Lane Area, W1K           House  45000000
# 3                    Pitt Street, Kensington, W8           House  44000000
# 4                        Pitt Street, London, W8        Detached  44000000
# ..                                           ...             ...       ...
# 674                         Mare Street, Hackney            flat    400000
# 675                    Ingleby Gardens, Chigwell   semi-detached    650000
# 676                    Inglewood Close, Hainault        terraced    350000
# 677                        Turner Avenue, London      maisonette    350000
# 678                   Knights Hill, West Norwood            flat    445000
#
#      No_of_Bedroom  No_of_Bathroom  \
# 0                3               1
# 1                7               9
# 2               12              18
# 3                6               5
# 4                7               5
# ..             ...             ...
# 674              1               1
# 675              3               1
# 676              3               1
# 677              4               1
# 678              3               1
#
#                                            Description  \
# 0    A truly unique and stunning three bedroom peri...
# 1    Ref. LOB0798 - Set behind a gated Belgravia dr...
# 2    This stunning 12 bedroom (including 3 staff be...
# 3    Ref. LOB0625 - This striking and unique house ...
# 4    A rare opportunity to own this unique, contemp...
# ..                                                 ...
# 674                            1 bedroom flat for sale
# 675             3 bedroom semi-detached house for sale
# 676                  3 bedroom terraced house for sale
# 677                      4 bedroom maisonette for sale
# 678                            3 bedroom flat for sale
#
#                                     Agent_name  \
# 0                    Stirling Ackroyd, Clapton
# 1      Beauchamp Estates Ltd, Mayfair - Resale
# 2    Luxury Living Homes International, London
# 3      Beauchamp Estates Ltd, Mayfair - Resale
# 4                          Savills, Kensington
# ..                                         ...
# 674                       Wild & Co. - Hackney
# 675                     Bowden Bradley - Essex
# 676                     Bowden Bradley - Essex
# 677                     Bowden Bradley - Essex
# 678  Kinleigh Folkard & Hayward - West Dulwich
#
#                                          Agent_website  \
# 0    https://www.rightmove.co.uk/estate-agents/agen...
# 1    https://www.rightmove.co.uk/estate-agents/agen...
# 2    https://www.rightmove.co.uk/estate-agents/agen...
# 3    https://www.rightmove.co.uk/estate-agents/agen...
# 4    https://www.rightmove.co.uk/estate-agents/agen...
# ..                                                 ...
# 674  https://www.onthemarket.com/agents/branch/wild...
# 675  https://www.onthemarket.com/agents/branch/bowd...
# 676  https://www.onthemarket.com/agents/branch/bowd...
# 677  https://www.onthemarket.com/agents/branch/bowd...
# 678  https://www.onthemarket.com/agents/branch/kinl...
#
#                                          Agent_contact  \
# 0    https://www.rightmove.co.uk/property-for-sale/...
# 1    https://www.rightmove.co.uk/property-for-sale/...
# 2    https://www.rightmove.co.uk/property-for-sale/...
# 3    https://www.rightmove.co.uk/property-for-sale/...
# 4    https://www.rightmove.co.uk/property-for-sale/...
# ..                                                 ...
# 674                                                NaN
# 675                                                NaN
# 676                                                NaN
# 677                                                NaN
# 678                                                NaN
#
#                                            Listing_url Transaction_type  \
# 0    https://www.rightmove.co.uk/properties/1352692...            sales
# 1    https://www.rightmove.co.uk/properties/1293029...            sales
# 2    https://www.rightmove.co.uk/properties/1303065...            sales
# 3    https://www.rightmove.co.uk/properties/1318567...            sales
# 4    https://www.rightmove.co.uk/properties/1318464...            sales
# ..                                                 ...              ...
# 674      https://www.onthemarket.com/details/13256622/             sale
# 675      https://www.onthemarket.com/details/13152350/             sale
# 676      https://www.onthemarket.com/details/13114711/             sale
# 677      https://www.onthemarket.com/details/13256406/             sale
# 678      https://www.onthemarket.com/details/12273929/             sale
#
#     Postcode_district  No_of_livingroom
# 0                  E5               NaN
# 1                SW1W               NaN
# 2                 W1K               NaN
# 3                  W8               NaN
# 4                  W8               NaN
# ..                ...               ...
# 674                E8               NaN
# 675               IG7               NaN
# 676               IG6               NaN
# 677               N15               NaN
# 678              SE27               NaN
#
# [2290 rows x 13 columns]

# %%
#Merging the List with the Postcode data available so as to get the exact location of these Properties
sales_data =  pd.merge(postcode_dist,sales,left_on = 'Postcode district',right_on = 'Postcode_district',how = 'inner')

# %%
#Checking for duplicated properties.
sales_data.duplicated().sum()
# Out:
# 22

# %%
#Some website may be listed on Multiple websites, so we need to get a unique list of properties.
sales_data = sales_data.drop_duplicates()

# %%
sales_data
# Out:
#      Postcode district                Local Areas      Borough  \
# 0                  BR1  Bromley, Bickley, Downham      Bromley
# 1                  BR1  Bromley, Bickley, Downham      Bromley
# 2                  BR1  Bromley, Bickley, Downham      Bromley
# 3                  BR1  Bromley, Bickley, Downham      Bromley
# 4                  BR1  Bromley, Bickley, Downham      Bromley
# ...                ...                        ...          ...
# 2233              WC2N              Charing Cross  Westminster
# 2234              WC2R             Somerset House  Westminster
# 2235              WC2R             Somerset House  Westminster
# 2236              WC2R             Somerset House  Westminster
# 2237              WC2R             Somerset House  Westminster
#
#                                     Address Property_type    Price  \
# 0                 Spencer Road, Bromley BR1          town   525000
# 1                  Rodway Road, Bromley BR1          flat   475000
# 2     Rangefield Road, Downham, Bromley BR1           end   450000
# 3                College Road, Bromley, BR1      detached  1150000
# 4              Faro Close, Bromley, BR1 2RR          flat   300000
# ...                                     ...           ...      ...
# 2233                         Strand, London     Apartment  6000000
# 2234                  190, The Strand, WC2R     Apartment  6500000
# 2235                   Strand, London, WC2R     Apartment  5999995
# 2236                   Strand, London, WC2R     Apartment  5999995
# 2237                    St Pancras Chambers     Apartment  9950000
#
#       No_of_Bedroom  No_of_Bathroom  \
# 0                 3               2
# 1                 2               2
# 2                 3               1
# 3                 6               3
# 4                 1               1
# ...             ...             ...
# 2233              3               3
# 2234              3               3
# 2235              3               3
# 2236              3               3
# 2237              3               2
#
#                                             Description  \
# 0                             3 bed town house for sale
# 1                                   2 bed flat for sale
# 2                      3 bed end terrace house for sale
# 3                     6 bedroom detached house for sale
# 4                               1 bedroom flat for sale
# ...                                                 ...
# 2233                              3bedrooms 3bathrooms.
# 2234  A spacious and bright three bedroom apartment ...
# 2235  A spacious and bright three bedroom apartment ...
# 2236  A spacious and bright three bedroom apartment ...
# 2237  A rare and unique opportunity to acquire the m...
#
#                                             Agent_name  \
# 0                                   Proctors - Bromley
# 1                           Langford Russell - Bromley
# 2                                      BR Estate Agent
# 3                                    Foxtons - Bromley
# 4                      Hunters - Chislehurst & Bromley
# ...                                                ...
# 2233       CHARLES WILLIAM PROPERTY INVESTMENT, London
# 2234                         Citian & Partners, London
# 2235  Life Residential, County Hall - South Bank Sales
# 2236  Life Residential, County Hall - South Bank Sales
# 2237                              London House, London
#
#                                           Agent_website  \
# 0     https://www.zoopla.co.uk/find-agents/branch/pr...
# 1     https://www.zoopla.co.uk/find-agents/branch/la...
# 2     https://www.zoopla.co.uk/find-agents/branch/br...
# 3     https://www.onthemarket.com/agents/branch/foxt...
# 4     https://www.onthemarket.com/agents/branch/hunt...
# ...                                                 ...
# 2233  https://www.rightmove.co.uk/estate-agents/agen...
# 2234  https://www.rightmove.co.uk/estate-agents/agen...
# 2235  https://www.rightmove.co.uk/estate-agents/agen...
# 2236  https://www.rightmove.co.uk/estate-agents/agen...
# 2237  https://www.rightmove.co.uk/estate-agents/agen...
#
#                                           Agent_contact  \
# 0     https://www.zoopla.co.uk/for-sale/details/cont...
# 1     https://www.zoopla.co.uk/for-sale/details/cont...
# 2     https://www.zoopla.co.uk/for-sale/details/cont...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2233  https://www.rightmove.co.uk/property-for-sale/...
# 2234  https://www.rightmove.co.uk/property-for-sale/...
# 2235  https://www.rightmove.co.uk/property-for-sale/...
# 2236  https://www.rightmove.co.uk/property-for-sale/...
# 2237  https://www.rightmove.co.uk/property-for-sale/...
#
#                                             Listing_url Transaction_type  \
# 0     https://www.zoopla.co.uk/for-sale/details/6472...             sale
# 1     https://www.zoopla.co.uk/for-sale/details/6472...             sale
# 2     https://www.zoopla.co.uk/for-sale/details/6472...             sale
# 3         https://www.onthemarket.com/details/13187264/             sale
# 4         https://www.onthemarket.com/details/13257555/             sale
# ...                                                 ...              ...
# 2233  https://www.rightmove.co.uk/properties/1325462...            sales
# 2234  https://www.rightmove.co.uk/properties/1326518...            sales
# 2235  https://www.rightmove.co.uk/properties/1252798...            sales
# 2236  https://www.rightmove.co.uk/properties/1252798...            sales
# 2237  https://www.rightmove.co.uk/properties/1283601...            sales
#
#      Postcode_district  No_of_livingroom
# 0                  BR1               2.0
# 1                  BR1               1.0
# 2                  BR1               2.0
# 3                  BR1               NaN
# 4                  BR1               NaN
# ...                ...               ...
# 2233              WC2N               NaN
# 2234              WC2R               NaN
# 2235              WC2R               NaN
# 2236              WC2R               NaN
# 2237              WC2R               NaN
#
# [2216 rows x 16 columns]

# %%
sales_data.to_csv('master_sales.csv',index = False)

# %%
#Getting the master list of all properties available for rent.
rent = pd.concat([rightmove_rent,zoopla_rent,otm_rent])

# %%
rent
# Out:
#                                       Address   Property_type  Price_pcm  \
# 0    Blythwood Road, Stroud Green, London, N4  End of Terrace       5250
# 1             Kingfisher Heights, London, E16            Flat       1850
# 2                Torriano Avenue, London, NW5            Flat       4500
# 3                 Ringstead Road, London, SE6            Flat       1460
# 4                      A Millway, London, NW7      Maisonette       1800
# ..                                        ...             ...        ...
# 627                       Nicoll Road, London            flat       1995
# 628                     Ashfield Road, London           house       3600
# 629                    Lancaster Road, Barnet            flat       1400
# 630                       Avenue Road, London            flat       1800
# 631                  East Barnet Road, Barnet            flat       2100
#
#      Price_pw  No_of_Bedroom  No_of_Bathroom  \
# 0        1212              5               2
# 1         427              1               1
# 2        1038              1               1
# 3         337              1               1
# 4         415              2               1
# ..        ...            ...             ...
# 627       460              2               1
# 628       831              4               1
# 629       323              1               1
# 630       415              2               1
# 631       485              3               1
#
#                                            Description  \
# 0    NO DEPOSIT OPTION AVAILABLE. Lovely five bedro...
# 1    Property Description: This beautiful one bedro...
# 2    A wonderfully stylish 1 bedroom apartment loca...
# 3    We are proud to offer this delightful 1 bedroo...
# 4    We are proud to offer this delightful 2 bedroo...
# ..                                                 ...
# 627                             2 bedroom flat to rent
# 628                            4 bedroom house to rent
# 629                             1 bedroom flat to rent
# 630                             2 bedroom flat to rent
# 631                             3 bedroom flat to rent
#
#                      Agent_name  \
# 0    Martyn Gerrard, Crouch End
# 1              OpenRent, London
# 2              OpenRent, London
# 3              OpenRent, London
# 4              OpenRent, London
# ..                          ...
# 627   Sunshine Estates - London
# 628   Sunshine Estates - London
# 629   Sunshine Estates - London
# 630   Sunshine Estates - London
# 631   Sunshine Estates - London
#
#                                          Agent_website  \
# 0    https://www.rightmove.co.uk/estate-agents/agen...
# 1    https://www.rightmove.co.uk/estate-agents/agen...
# 2    https://www.rightmove.co.uk/estate-agents/agen...
# 3    https://www.rightmove.co.uk/estate-agents/agen...
# 4    https://www.rightmove.co.uk/estate-agents/agen...
# ..                                                 ...
# 627  https://www.onthemarket.com/agents/branch/suns...
# 628  https://www.onthemarket.com/agents/branch/suns...
# 629  https://www.onthemarket.com/agents/branch/suns...
# 630  https://www.onthemarket.com/agents/branch/suns...
# 631  https://www.onthemarket.com/agents/branch/suns...
#
#                                          Agent_contact  \
# 0    https://www.rightmove.co.uk/property-to-rent/c...
# 1    https://www.rightmove.co.uk/property-to-rent/c...
# 2    https://www.rightmove.co.uk/property-to-rent/c...
# 3    https://www.rightmove.co.uk/property-to-rent/c...
# 4    https://www.rightmove.co.uk/property-to-rent/c...
# ..                                                 ...
# 627                                                NaN
# 628                                                NaN
# 629                                                NaN
# 630                                                NaN
# 631                                                NaN
#
#                                            Listing_url Postcode_district  \
# 0    https://www.rightmove.co.uk/properties/1352645...                N4
# 1    https://www.rightmove.co.uk/properties/1354085...                E1
# 2    https://www.rightmove.co.uk/properties/1354085...               NW5
# 3    https://www.rightmove.co.uk/properties/1354085...                E6
# 4    https://www.rightmove.co.uk/properties/1354085...               NW7
# ..                                                 ...               ...
# 627      https://www.onthemarket.com/details/13258607/              NW10
# 628      https://www.onthemarket.com/details/13258602/                N4
# 629      https://www.onthemarket.com/details/13258598/               EN4
# 630      https://www.onthemarket.com/details/13258597/               BR3
# 631      https://www.onthemarket.com/details/13182824/               EN4
#
#     Transaction_type  No_of_livingroom
# 0               rent               NaN
# 1               rent               NaN
# 2               rent               NaN
# 3               rent               NaN
# 4               rent               NaN
# ..               ...               ...
# 627             rent               NaN
# 628             rent               NaN
# 629             rent               NaN
# 630             rent               NaN
# 631             rent               NaN
#
# [2386 rows x 14 columns]

# %%
#Getting the exact location of where they are located by merging with the District zipcode of London available.
rent_data =  pd.merge(postcode_dist,rent,left_on = 'Postcode district',right_on = 'Postcode_district',how = 'inner')

# %%
#Checking for multiple listing.
rent_data.duplicated().sum()
# Out:
# 126

# %%
#Removing multiple listing
rent_data = rent_data.drop_duplicates()

# %%
rent_data
# Out:
#      Postcode district                Local Areas      Borough  \
# 0                  BR1  Bromley, Bickley, Downham      Bromley
# 2                  BR1  Bromley, Bickley, Downham      Bromley
# 3                  BR1  Bromley, Bickley, Downham      Bromley
# 4                  BR1  Bromley, Bickley, Downham      Bromley
# 5                  BR1  Bromley, Bickley, Downham      Bromley
# ...                ...                        ...          ...
# 2365              WC2N              Charing Cross  Westminster
# 2366              WC2R             Somerset House  Westminster
# 2367              WC2R             Somerset House  Westminster
# 2368              WC2R             Somerset House  Westminster
# 2369              WC2R             Somerset House  Westminster
#
#                                                 Address Property_type  \
# 0                            Chelford Road, Bromley BR1          flat
# 2                             Widmore Road, Bromley BR1          flat
# 3                              Palace Road, Bromley BR1      property
# 4                            Widmore Road, Bromley, BR1     apartment
# 5                            Widmore Road, Bromley, BR1     apartment
# ...                                                 ...           ...
# 2365                  Craven Street, Charing Cross WC2N          flat
# 2366                               Strand, London, WC2R     Apartment
# 2367                    Strand, The Strand, London WC2R          flat
# 2368  Gladstone House, 190 The Strand, 190 The Stran...          flat
# 2369                                Strand, London WC2R          flat
#
#       Price_pcm  Price_pw  No_of_Bedroom  No_of_Bathroom  \
# 0          1700       392              2               2
# 2          1900       438              2               2
# 3          1600       369              2               1
# 4          1900       438              2               2
# 5          1550       358              1               1
# ...         ...       ...            ...             ...
# 2365       2037       470              1               1
# 2366       7150      1650              2               2
# 2367       6500      1500              1               1
# 2368       7150      1650              2               2
# 2369       7150      1650              2               2
#
#                                             Description  \
# 0                                    2 bed flat to rent
# 2                                    2 bed flat to rent
# 3                                2 bed property to rent
# 4                           2 bedroom apartment to rent
# 5                           1 bedroom apartment to rent
# ...                                                 ...
# 2365                                 1 bed flat to rent
# 2366  Beautifully presented two bedroom apartment wi...
# 2367                                 1 bed flat to rent
# 2368                                 2 bed flat to rent
# 2369                                 2 bed flat to rent
#
#                                      Agent_name  \
# 0           Andrew Reeves Countrywide - Bromley
# 2                                    Leo Newman
# 3           Andrew Reeves Countrywide - Bromley
# 4                           Leo Newman - London
# 5                           Leo Newman - London
# ...                                         ...
# 2365                          SN Estates London
# 2366                  Savills Lettings, Mayfair
# 2367                         Foxtons - West End
# 2368                           Chase Apartments
# 2369  Savills - Mayfair & St Jamesâs Lettings
#
#                                           Agent_website  \
# 0     https://www.zoopla.co.uk/find-agents/branch/an...
# 2     https://www.zoopla.co.uk/find-agents/branch/le...
# 3     https://www.zoopla.co.uk/find-agents/branch/an...
# 4     https://www.onthemarket.com/agents/branch/leo-...
# 5     https://www.onthemarket.com/agents/branch/leo-...
# ...                                                 ...
# 2365  https://www.zoopla.co.uk/find-agents/branch/sn...
# 2366  https://www.rightmove.co.uk/estate-agents/agen...
# 2367  https://www.zoopla.co.uk/find-agents/branch/fo...
# 2368  https://www.zoopla.co.uk/find-agents/branch/ch...
# 2369  https://www.zoopla.co.uk/find-agents/branch/sa...
#
#                                           Agent_contact  \
# 0     https://www.zoopla.co.uk/to-rent/details/conta...
# 2     https://www.zoopla.co.uk/to-rent/details/conta...
# 3     https://www.zoopla.co.uk/to-rent/details/conta...
# 4                                                   NaN
# 5                                                   NaN
# ...                                                 ...
# 2365  https://www.zoopla.co.uk/to-rent/details/conta...
# 2366  https://www.rightmove.co.uk/property-to-rent/c...
# 2367  https://www.zoopla.co.uk/to-rent/details/conta...
# 2368  https://www.zoopla.co.uk/to-rent/details/conta...
# 2369  https://www.zoopla.co.uk/to-rent/details/conta...
#
#                                             Listing_url Postcode_district  \
# 0     https://www.zoopla.co.uk/to-rent/details/64732...               BR1
# 2     https://www.zoopla.co.uk/to-rent/details/64728...               BR1
# 3     https://www.zoopla.co.uk/to-rent/details/55479...               BR1
# 4         https://www.onthemarket.com/details/13262988/               BR1
# 5         https://www.onthemarket.com/details/13259222/               BR1
# ...                                                 ...               ...
# 2365  https://www.zoopla.co.uk/to-rent/details/43648...              WC2N
# 2366  https://www.rightmove.co.uk/properties/1353678...              WC2R
# 2367  https://www.zoopla.co.uk/to-rent/details/64731...              WC2R
# 2368  https://www.zoopla.co.uk/to-rent/details/64731...              WC2R
# 2369  https://www.zoopla.co.uk/to-rent/details/64728...              WC2R
#
#      Transaction_type  No_of_livingroom
# 0                rent               1.0
# 2                rent               1.0
# 3                rent               1.0
# 4                rent               NaN
# 5                rent               NaN
# ...               ...               ...
# 2365             rent               NaN
# 2366             rent               NaN
# 2367             rent               1.0
# 2368             rent               1.0
# 2369             rent               1.0
#
# [2244 rows x 17 columns]

# %%
rent_data.to_csv('master_rent.csv',index = False)

# %% [markdown]
# ## END NOTE

# %% [markdown]
# I'm delighted to have completed this project, and it has been more than just a competition for me. Throughout this project, I had the opportunity to enhance my analytical and programming skills. Among the three websites, I encountered the most challenges when gathering data from Zoopla due to its bot detection measures. However, with extensive research and learning, I managed to overcome these obstacles and find a way forward. This experience has exposed me to a variety of web scraping packages, expanding my knowledge in this area. I extend my heartfelt appreciation to the organizers of this competition for granting me the opportunity to participate.
